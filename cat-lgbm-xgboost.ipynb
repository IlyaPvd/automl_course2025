# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 22.8 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
import numpy as np
import pandas as pd
import warnings

from sklearn.model_selection import train_test_split
import catboost as cb
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import xgboost as xgb

warnings.filterwarnings('ignore')

# Configure pandas display settings for better data visualization
pd.options.display.max_columns = None

def preprocess_numerical_features(df):
    """
    Handle numerical features by converting strings to numbers and imputing missing values.
    Args:
        df: Input DataFrame
    Returns:
        DataFrame with processed numerical features
    """
    # Fill missing values with median
    df['person_emp_length'] = df['person_emp_length'].fillna(df['person_emp_length'].median())
    df['loan_int_rate'] = df['loan_int_rate'].fillna(df['loan_int_rate'].median())

    # Convert to appropriate numeric types
    df['person_emp_length'] = df['person_emp_length'].astype(int)
    df['loan_int_rate'] = (df['loan_int_rate'] * 100).astype(int)
    df['loan_percent_income'] = (df['loan_percent_income'] * 100).astype(int)

    return df

def encode_categorical_features(df):
    """
    Convert categorical variables to appropriate data types and encode them.
    Args:
        df: Input DataFrame
    Returns:
        DataFrame with encoded categorical features
    """
    categorical_mappings = {
        'person_home_ownership': {'RENT': 0, 'MORTGAGE': 1, 'OWN': 2, 'OTHER': 3},
        'loan_intent': {'EDUCATION': 0, 'MEDICAL': 1, 'PERSONAL': 2, 'VENTURE': 3,
                       'DEBTCONSOLIDATION': 4, 'HOMEIMPROVEMENT': 5},
        'loan_grade': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6},
        'cb_person_default_on_file': {'N': 0, 'Y': 1}
    }

    for col, mapping in categorical_mappings.items():
        df[col] = df[col].replace(mapping)

    return df

def engineer_credit_features(df):
    """
    Create advanced features for credit risk assessment.
    Args:
        df: Input DataFrame
    Returns:
        DataFrame with additional engineered features
    """
    # Calculate financial ratios and interactions with safety checks
    df['debt_to_income'] = np.clip(
        ((df['loan_amnt'] / df['person_income']) - df['loan_percent_income']),
        -1e6, 1e6
    )
    df['age_income_factor'] = np.clip(
        (df['person_age'] * df['person_income']),
        0, 1e9
    )
    # Avoid division by zero in employment ratio
    df['loan_employment_ratio'] = np.clip(
        df['loan_amnt'] / df['person_emp_length'].replace(0, 1),
        0, 1e6
    )

    # Monthly financial calculations with safety checks
    monthly_income = np.maximum(df['person_income'] / 12, 1)  # Ensure no zero division
    df['monthly_loan_payment'] = np.clip(
        (df['loan_amnt'] * (1 + df['loan_int_rate']/100) / 12),
        0, 1e6
    )
    df['monthly_debt_ratio'] = np.clip(
        (df['monthly_loan_payment'] / monthly_income),
        0, 1e2
    )

    # Risk assessment feature
    df['credit_risk_indicator'] = np.where(
        (df['cb_person_default_on_file'] == 1) &
        (df['loan_grade'].isin([2, 3, 4])),
        1, 0
    )

    # Normalize loan-to-income ratio with safety check
    df["normalized_loan_income_ratio"] = np.clip(
        ((df["loan_amnt"] / np.maximum(df["person_income"], 1)) * 1000000),
        0, 1e9
    ).astype(int)

    return df

# Load datasets
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/test.csv')
supplementary_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/credit_risk_dataset.csv')
submission = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sample_submission.csv')


# Initial data preparation
train = pd.concat([train, supplementary_data], ignore_index=True)

# Apply preprocessing steps
train = preprocess_numerical_features(train)
train = encode_categorical_features(train)
train = engineer_credit_features(train)

test = preprocess_numerical_features(test)
test = encode_categorical_features(test)
test = engineer_credit_features(test)

# Prepare features and target
X = train.drop(['loan_status', 'id'], axis=1)
y = train['loan_status']
test = test.drop(['id'], axis=1)

# Define model parameters
catboost_params = {
    'task_type': "GPU",  # Use GPU acceleration
    'devices': '0',  # Use first GPU
    'loss_function': 'Logloss',
    'eval_metric': "AUC",
    'iterations': 5000,
    'learning_rate': 0.045,
    'max_depth': 7,
    'l2_leaf_reg': 0.80,
    'min_data_in_leaf': 30,
    'random_state': 42,
    'early_stopping_rounds': 200,
    'use_best_model': False,
    'allow_writing_files': False,
    'bootstrap_type': 'Bernoulli',  # GPU-compatible bootstrap type
    'subsample': 0.8,  # Instead of bagging_temperature
    'gpu_ram_part': 0.95  # Use 95% of GPU memory
}

lgbm_params = {
    'n_estimators': 1779,
    'learning_rate': 0.018971107281482297,
    'num_leaves': 100,
    'max_depth': 13,
    'min_child_samples': 6,
    'subsample': 0.9557780001541148,
    'colsample_bytree': 0.6125766049856997,
    'reg_alpha': 2.2391090634191215,
    'reg_lambda': 0.023135194031906982,
    'random_state': 42,
    'n_jobs': -1  # Use all CPU cores
}

xgb_params = {
    'max_depth': 9,
    'learning_rate': 0.09763827013301708,
    'n_estimators': 929,
    'min_child_weight': 2,
    'gamma': 0.0737000842530037,
    'subsample': 0.999299053610849,
    'colsample_bytree': 0.7331921391500718,
    'reg_alpha': 1.5593266144989077,
    'reg_lambda': 2.2285698685927673,
    'scale_pos_weight': 1.4106632040101776,
    'tree_method': 'gpu_hist',  # Use GPU histogram method
    'device': 'cuda',  # Use CUDA for GPU acceleration
    'random_state': 42
}

# Data validation and cleaning
def clean_infinite_values(df):
    """
    Clean infinite values from dataframe and ensure all numeric columns are within reasonable bounds
    Args:
        df: Input DataFrame
    Returns:
        DataFrame with cleaned values
    """
    # Replace infinities with NaN first
    df = df.replace([np.inf, -np.inf], np.nan)

    # For each numeric column, clip values to reasonable bounds
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    for col in numeric_cols:
        df[col] = np.clip(df[col].fillna(df[col].median()), -1e9, 1e9)

    return df

# Clean data before training
print("Cleaning training data...")
X = clean_infinite_values(X)
print("Cleaning test data...")
test = clean_infinite_values(test)

# Train models
print("Training CatBoost model...")
catboost_model = CatBoostClassifier(**catboost_params)
catboost_model.fit(X, y)

print("Training LightGBM model...")
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model.fit(X, y)

print("Training XGBoost model...")
xgb_model = xgb.XGBClassifier(**xgb_params)
xgb_model.fit(X, y)

# Generate predictions
pred_catboost = catboost_model.predict_proba(test)[:, 1]
pred_lgbm = lgbm_model.predict_proba(test)[:, 1]
pred_xgb = xgb_model.predict_proba(test)[:, 1]

# Create ensemble predictions
submission['loan_status'] = (pred_catboost + pred_lgbm + pred_xgb) / 3
submission.to_csv('submission.csv', index=False)
# Out:
# Cleaning training data...
# Cleaning test data...
# Training CatBoost model...
# Default metric period is 5 because AUC is/are not implemented for GPU
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 10:	total: 69.3ms	remaining: 31.4s
# 11:	total: 75.4ms	remaining: 31.4s
# 12:	total: 81.6ms	remaining: 31.3s
# 13:	total: 87.7ms	remaining: 31.2s
# 14:	total: 93.8ms	remaining: 31.2s
# 15:	total: 100ms	remaining: 31.3s
# 16:	total: 107ms	remaining: 31.3s
# 17:	total: 113ms	remaining: 31.2s
# 18:	total: 119ms	remaining: 31.2s
# 19:	total: 125ms	remaining: 31.2s
# 20:	total: 132ms	remaining: 31.2s
# 21:	total: 138ms	remaining: 31.2s
# 22:	total: 144ms	remaining: 31.2s
# 23:	total: 150ms	remaining: 31.1s
# 24:	total: 156ms	remaining: 31.1s
# 25:	total: 163ms	remaining: 31.1s
# 26:	total: 169ms	remaining: 31.2s
# 27:	total: 176ms	remaining: 31.3s
# 28:	total: 183ms	remaining: 31.3s
# 29:	total: 190ms	remaining: 31.4s
# 30:	total: 197ms	remaining: 31.6s
# 31:	total: 203ms	remaining: 31.6s
# 32:	total: 210ms	remaining: 31.6s
# 33:	total: 216ms	remaining: 31.6s
# 34:	total: 223ms	remaining: 31.6s
# 35:	total: 229ms	remaining: 31.5s
# 36:	total: 235ms	remaining: 31.5s
# 37:	total: 241ms	remaining: 31.5s
# 38:	total: 247ms	remaining: 31.4s
# 39:	total: 253ms	remaining: 31.4s
# 40:	total: 259ms	remaining: 31.4s
# 41:	total: 265ms	remaining: 31.3s
# 42:	total: 272ms	remaining: 31.3s
# 43:	total: 278ms	remaining: 31.3s
# 44:	total: 284ms	remaining: 31.3s
# 45:	total: 290ms	remaining: 31.3s
# 46:	total: 296ms	remaining: 31.2s
# 47:	total: 303ms	remaining: 31.2s
# 48:	total: 309ms	remaining: 31.2s
# 49:	total: 314ms	remaining: 31.1s
# 50:	total: 320ms	remaining: 31s
# 51:	total: 325ms	remaining: 30.9s
# 52:	total: 330ms	remaining: 30.8s
# 53:	total: 335ms	remaining: 30.7s
# 54:	total: 341ms	remaining: 30.6s
# 55:	total: 346ms	remaining: 30.5s
# 56:	total: 351ms	remaining: 30.4s
# 57:	total: 357ms	remaining: 30.4s
# 58:	total: 362ms	remaining: 30.3s
# 59:	total: 367ms	remaining: 30.2s
# 60:	total: 373ms	remaining: 30.2s
# 61:	total: 378ms	remaining: 30.1s
# 62:	total: 384ms	remaining: 30.1s
# 63:	total: 389ms	remaining: 30s
# 64:	total: 395ms	remaining: 30s
# 65:	total: 400ms	remaining: 29.9s
# 66:	total: 406ms	remaining: 29.9s
# 67:	total: 411ms	remaining: 29.8s
# 68:	total: 416ms	remaining: 29.8s
# 69:	total: 422ms	remaining: 29.7s
# 70:	total: 427ms	remaining: 29.6s
# 71:	total: 432ms	remaining: 29.6s
# 72:	total: 438ms	remaining: 29.5s
# 73:	total: 443ms	remaining: 29.5s
# 74:	total: 448ms	remaining: 29.4s
# 75:	total: 454ms	remaining: 29.4s
# 76:	total: 460ms	remaining: 29.4s
# 77:	total: 465ms	remaining: 29.3s
# 78:	total: 470ms	remaining: 29.3s
# 79:	total: 476ms	remaining: 29.3s
# 80:	total: 481ms	remaining: 29.2s
# 81:	total: 487ms	remaining: 29.2s
# 82:	total: 492ms	remaining: 29.2s
# 83:	total: 498ms	remaining: 29.1s
# 84:	total: 503ms	remaining: 29.1s
# 85:	total: 509ms	remaining: 29.1s
# 86:	total: 514ms	remaining: 29s
# 87:	total: 520ms	remaining: 29s
# 88:	total: 525ms	remaining: 29s
# 89:	total: 530ms	remaining: 28.9s
# 90:	total: 536ms	remaining: 28.9s
# 91:	total: 541ms	remaining: 28.9s
# 92:	total: 547ms	remaining: 28.8s
# 93:	total: 552ms	remaining: 28.8s
# 94:	total: 557ms	remaining: 28.8s
# 95:	total: 563ms	remaining: 28.8s
# 96:	total: 568ms	remaining: 28.7s
# 97:	total: 574ms	remaining: 28.7s
# 98:	total: 579ms	remaining: 28.7s
# 99:	total: 585ms	remaining: 28.6s
# 100:	total: 590ms	remaining: 28.6s
# 101:	total: 595ms	remaining: 28.6s
# 102:	total: 601ms	remaining: 28.6s
# 103:	total: 606ms	remaining: 28.5s
# 104:	total: 612ms	remaining: 28.5s
# 105:	total: 617ms	remaining: 28.5s
# 106:	total: 623ms	remaining: 28.5s
# 107:	total: 628ms	remaining: 28.4s
# 108:	total: 633ms	remaining: 28.4s
# 109:	total: 639ms	remaining: 28.4s
# 110:	total: 644ms	remaining: 28.4s
# 111:	total: 650ms	remaining: 28.4s
# 112:	total: 655ms	remaining: 28.3s
# 113:	total: 661ms	remaining: 28.3s
# 114:	total: 666ms	remaining: 28.3s
# 115:	total: 671ms	remaining: 28.3s
# 116:	total: 677ms	remaining: 28.2s
# 117:	total: 682ms	remaining: 28.2s
# 118:	total: 688ms	remaining: 28.2s
# 119:	total: 693ms	remaining: 28.2s
# 120:	total: 699ms	remaining: 28.2s
# 121:	total: 704ms	remaining: 28.2s
# 122:	total: 710ms	remaining: 28.1s
# 123:	total: 715ms	remaining: 28.1s
# 124:	total: 721ms	remaining: 28.1s
# 125:	total: 727ms	remaining: 28.1s
# 126:	total: 732ms	remaining: 28.1s
# 127:	total: 738ms	remaining: 28.1s
# 128:	total: 744ms	remaining: 28.1s
# 129:	total: 749ms	remaining: 28.1s
# 130:	total: 755ms	remaining: 28.1s
# 131:	total: 761ms	remaining: 28.1s
# 132:	total: 767ms	remaining: 28.1s
# 133:	total: 772ms	remaining: 28s
# 134:	total: 778ms	remaining: 28s
# 135:	total: 784ms	remaining: 28s
# 136:	total: 790ms	remaining: 28s
# 137:	total: 795ms	remaining: 28s
# 138:	total: 801ms	remaining: 28s
# 139:	total: 807ms	remaining: 28s
# 140:	total: 813ms	remaining: 28s
# 141:	total: 818ms	remaining: 28s
# 142:	total: 824ms	remaining: 28s
# 143:	total: 829ms	remaining: 28s
# 144:	total: 835ms	remaining: 28s
# 145:	total: 841ms	remaining: 27.9s
# 146:	total: 846ms	remaining: 27.9s
# 147:	total: 852ms	remaining: 27.9s
# 148:	total: 857ms	remaining: 27.9s
# 149:	total: 863ms	remaining: 27.9s
# 150:	total: 868ms	remaining: 27.9s
# 151:	total: 874ms	remaining: 27.9s
# 152:	total: 880ms	remaining: 27.9s
# 153:	total: 886ms	remaining: 27.9s
# 154:	total: 891ms	remaining: 27.9s
# 155:	total: 897ms	remaining: 27.9s
# 156:	total: 903ms	remaining: 27.9s
# 157:	total: 909ms	remaining: 27.9s
# 158:	total: 915ms	remaining: 27.9s
# 159:	total: 921ms	remaining: 27.9s
# 160:	total: 927ms	remaining: 27.9s
# 161:	total: 933ms	remaining: 27.9s
# 162:	total: 939ms	remaining: 27.9s
# 163:	total: 944ms	remaining: 27.8s
# 164:	total: 950ms	remaining: 27.8s
# 165:	total: 955ms	remaining: 27.8s
# 166:	total: 961ms	remaining: 27.8s
# 167:	total: 966ms	remaining: 27.8s
# 168:	total: 971ms	remaining: 27.8s
# 169:	total: 977ms	remaining: 27.7s
# 170:	total: 982ms	remaining: 27.7s
# 171:	total: 988ms	remaining: 27.7s
# 172:	total: 994ms	remaining: 27.7s
# 173:	total: 1s	remaining: 27.7s
# 174:	total: 1s	remaining: 27.7s
# 175:	total: 1.01s	remaining: 27.7s
# 176:	total: 1.02s	remaining: 27.8s
# 177:	total: 1.02s	remaining: 27.8s
# 178:	total: 1.03s	remaining: 27.8s
# 179:	total: 1.03s	remaining: 27.7s
# 180:	total: 1.04s	remaining: 27.7s
# 181:	total: 1.05s	remaining: 27.7s
# 182:	total: 1.05s	remaining: 27.7s
# 183:	total: 1.06s	remaining: 27.7s
# 184:	total: 1.06s	remaining: 27.6s
# 185:	total: 1.07s	remaining: 27.6s
# 186:	total: 1.07s	remaining: 27.6s
# 187:	total: 1.08s	remaining: 27.6s
# 188:	total: 1.08s	remaining: 27.6s
# 189:	total: 1.09s	remaining: 27.6s
# 190:	total: 1.09s	remaining: 27.6s
# 191:	total: 1.1s	remaining: 27.5s
# 192:	total: 1.1s	remaining: 27.5s
# 193:	total: 1.11s	remaining: 27.5s
# 194:	total: 1.11s	remaining: 27.5s
# 195:	total: 1.12s	remaining: 27.5s
# 196:	total: 1.13s	remaining: 27.5s
# 197:	total: 1.13s	remaining: 27.5s
# 198:	total: 1.14s	remaining: 27.5s
# 199:	total: 1.14s	remaining: 27.4s
# 200:	total: 1.15s	remaining: 27.4s
# 201:	total: 1.15s	remaining: 27.4s
# 202:	total: 1.16s	remaining: 27.4s
# 203:	total: 1.17s	remaining: 27.4s
# 204:	total: 1.17s	remaining: 27.4s
# 205:	total: 1.18s	remaining: 27.4s
# 206:	total: 1.18s	remaining: 27.4s
# 207:	total: 1.19s	remaining: 27.4s
# 208:	total: 1.19s	remaining: 27.4s
# 209:	total: 1.2s	remaining: 27.3s
# 210:	total: 1.2s	remaining: 27.3s
# 211:	total: 1.21s	remaining: 27.3s
# 212:	total: 1.22s	remaining: 27.4s
# 213:	total: 1.22s	remaining: 27.4s
# 214:	total: 1.23s	remaining: 27.4s
# 215:	total: 1.24s	remaining: 27.4s
# 216:	total: 1.24s	remaining: 27.4s
# 217:	total: 1.25s	remaining: 27.3s
# 218:	total: 1.25s	remaining: 27.3s
# 219:	total: 1.26s	remaining: 27.3s
# 220:	total: 1.26s	remaining: 27.3s
# 221:	total: 1.27s	remaining: 27.3s
# 222:	total: 1.27s	remaining: 27.3s
# 223:	total: 1.28s	remaining: 27.3s
# 224:	total: 1.29s	remaining: 27.3s
# 225:	total: 1.29s	remaining: 27.3s
# 226:	total: 1.3s	remaining: 27.3s
# 227:	total: 1.3s	remaining: 27.3s
# 228:	total: 1.31s	remaining: 27.3s
# 229:	total: 1.31s	remaining: 27.2s
# 230:	total: 1.32s	remaining: 27.2s
# 231:	total: 1.32s	remaining: 27.2s
# 232:	total: 1.33s	remaining: 27.2s
# 233:	total: 1.33s	remaining: 27.2s
# 234:	total: 1.34s	remaining: 27.2s
# 235:	total: 1.35s	remaining: 27.2s
# 236:	total: 1.35s	remaining: 27.2s
# 237:	total: 1.36s	remaining: 27.1s
# 238:	total: 1.36s	remaining: 27.1s
# 239:	total: 1.37s	remaining: 27.1s
# 240:	total: 1.37s	remaining: 27.1s
# 241:	total: 1.38s	remaining: 27.1s
# 242:	total: 1.38s	remaining: 27.1s
# 243:	total: 1.39s	remaining: 27.1s
# 244:	total: 1.39s	remaining: 27.1s
# 245:	total: 1.4s	remaining: 27.1s
# 246:	total: 1.41s	remaining: 27s
# 247:	total: 1.41s	remaining: 27s
# 248:	total: 1.42s	remaining: 27s
# 249:	total: 1.42s	remaining: 27s
# 250:	total: 1.43s	remaining: 27s
# 251:	total: 1.43s	remaining: 27s
# 252:	total: 1.44s	remaining: 27s
# 253:	total: 1.45s	remaining: 27s
# 254:	total: 1.45s	remaining: 27s
# 255:	total: 1.46s	remaining: 27s
# 256:	total: 1.47s	remaining: 27s
# 257:	total: 1.47s	remaining: 27s
# 258:	total: 1.48s	remaining: 27s
# 259:	total: 1.48s	remaining: 27s
# 260:	total: 1.49s	remaining: 27s
# 261:	total: 1.49s	remaining: 27s
# 262:	total: 1.5s	remaining: 27s
# 263:	total: 1.5s	remaining: 27s
# 264:	total: 1.51s	remaining: 27s
# 265:	total: 1.51s	remaining: 26.9s
# 266:	total: 1.52s	remaining: 26.9s
# 267:	total: 1.52s	remaining: 26.9s
# 268:	total: 1.53s	remaining: 26.9s
# 269:	total: 1.53s	remaining: 26.9s
# 270:	total: 1.54s	remaining: 26.9s
# 271:	total: 1.54s	remaining: 26.9s
# 272:	total: 1.55s	remaining: 26.8s
# 273:	total: 1.55s	remaining: 26.8s
# 274:	total: 1.56s	remaining: 26.8s
# 275:	total: 1.56s	remaining: 26.8s
# 276:	total: 1.57s	remaining: 26.8s
# 277:	total: 1.57s	remaining: 26.8s
# 278:	total: 1.58s	remaining: 26.8s
# 279:	total: 1.59s	remaining: 26.7s
# 280:	total: 1.59s	remaining: 26.7s
# 281:	total: 1.6s	remaining: 26.7s
# 282:	total: 1.6s	remaining: 26.7s
# 283:	total: 1.61s	remaining: 26.7s
# 284:	total: 1.61s	remaining: 26.7s
# 285:	total: 1.62s	remaining: 26.7s
# 286:	total: 1.62s	remaining: 26.6s
# 287:	total: 1.63s	remaining: 26.6s
# 288:	total: 1.63s	remaining: 26.6s
# 289:	total: 1.64s	remaining: 26.6s
# 290:	total: 1.64s	remaining: 26.6s
# 291:	total: 1.65s	remaining: 26.6s
# 292:	total: 1.65s	remaining: 26.6s
# 293:	total: 1.66s	remaining: 26.6s
# 294:	total: 1.66s	remaining: 26.5s
# 295:	total: 1.67s	remaining: 26.5s
# 296:	total: 1.67s	remaining: 26.5s
# 297:	total: 1.68s	remaining: 26.5s
# 298:	total: 1.69s	remaining: 26.5s
# 299:	total: 1.69s	remaining: 26.5s
# 300:	total: 1.7s	remaining: 26.5s
# 301:	total: 1.7s	remaining: 26.5s
# 302:	total: 1.71s	remaining: 26.4s
# 303:	total: 1.71s	remaining: 26.4s
# 304:	total: 1.72s	remaining: 26.4s
# 305:	total: 1.72s	remaining: 26.4s
# 306:	total: 1.73s	remaining: 26.4s
# 307:	total: 1.73s	remaining: 26.4s
# 308:	total: 1.74s	remaining: 26.4s
# 309:	total: 1.74s	remaining: 26.4s
# 310:	total: 1.75s	remaining: 26.4s
# 311:	total: 1.75s	remaining: 26.3s
# 312:	total: 1.76s	remaining: 26.3s
# 313:	total: 1.76s	remaining: 26.3s
# 314:	total: 1.77s	remaining: 26.3s
# 315:	total: 1.77s	remaining: 26.3s
# 316:	total: 1.78s	remaining: 26.3s
# 317:	total: 1.78s	remaining: 26.3s
# 318:	total: 1.79s	remaining: 26.3s
# 319:	total: 1.79s	remaining: 26.3s
# 320:	total: 1.8s	remaining: 26.2s
# 321:	total: 1.8s	remaining: 26.2s
# 322:	total: 1.81s	remaining: 26.2s
# 323:	total: 1.81s	remaining: 26.2s
# 324:	total: 1.82s	remaining: 26.2s
# 325:	total: 1.83s	remaining: 26.2s
# 326:	total: 1.83s	remaining: 26.2s
# 327:	total: 1.84s	remaining: 26.2s
# 328:	total: 1.84s	remaining: 26.2s
# 329:	total: 1.85s	remaining: 26.2s
# 330:	total: 1.85s	remaining: 26.2s
# 331:	total: 1.86s	remaining: 26.2s
# 332:	total: 1.86s	remaining: 26.1s
# 333:	total: 1.87s	remaining: 26.1s
# 334:	total: 1.88s	remaining: 26.1s
# 335:	total: 1.88s	remaining: 26.1s
# 336:	total: 1.89s	remaining: 26.1s
# 337:	total: 1.89s	remaining: 26.1s
# 338:	total: 1.9s	remaining: 26.1s
# 339:	total: 1.91s	remaining: 26.1s
# 340:	total: 1.91s	remaining: 26.1s
# 341:	total: 1.92s	remaining: 26.1s
# 342:	total: 1.92s	remaining: 26.1s
# 343:	total: 1.93s	remaining: 26.1s
# 344:	total: 1.93s	remaining: 26.1s
# 345:	total: 1.94s	remaining: 26.1s
# 346:	total: 1.94s	remaining: 26.1s
# 347:	total: 1.95s	remaining: 26.1s
# 348:	total: 1.96s	remaining: 26.1s
# 349:	total: 1.96s	remaining: 26.1s
# 350:	total: 1.97s	remaining: 26.1s
# 351:	total: 1.97s	remaining: 26.1s
# 352:	total: 1.98s	remaining: 26s
# 353:	total: 1.98s	remaining: 26s
# 354:	total: 1.99s	remaining: 26s
# 355:	total: 2s	remaining: 26s
# 356:	total: 2s	remaining: 26s
# 357:	total: 2.01s	remaining: 26s
# 358:	total: 2.01s	remaining: 26s
# 359:	total: 2.02s	remaining: 26s
# 360:	total: 2.02s	remaining: 26s
# 361:	total: 2.03s	remaining: 26s
# 362:	total: 2.04s	remaining: 26s
# 363:	total: 2.04s	remaining: 26s
# 364:	total: 2.05s	remaining: 26s
# 365:	total: 2.05s	remaining: 26s
# 366:	total: 2.06s	remaining: 26s
# 367:	total: 2.06s	remaining: 26s
# 368:	total: 2.07s	remaining: 26s
# 369:	total: 2.08s	remaining: 26s
# 370:	total: 2.08s	remaining: 26s
# 371:	total: 2.09s	remaining: 26s
# 372:	total: 2.09s	remaining: 26s
# 373:	total: 2.1s	remaining: 26s
# 374:	total: 2.11s	remaining: 26s
# 375:	total: 2.11s	remaining: 26s
# 376:	total: 2.12s	remaining: 26s
# 377:	total: 2.12s	remaining: 26s
# 378:	total: 2.13s	remaining: 26s
# 379:	total: 2.13s	remaining: 26s
# 380:	total: 2.14s	remaining: 26s
# 381:	total: 2.15s	remaining: 26s
# 382:	total: 2.15s	remaining: 26s
# 383:	total: 2.16s	remaining: 26s
# 384:	total: 2.16s	remaining: 26s
# 385:	total: 2.17s	remaining: 25.9s
# 386:	total: 2.18s	remaining: 25.9s
# 387:	total: 2.18s	remaining: 25.9s
# 388:	total: 2.19s	remaining: 25.9s
# 389:	total: 2.19s	remaining: 25.9s
# 390:	total: 2.2s	remaining: 25.9s
# 391:	total: 2.21s	remaining: 25.9s
# 392:	total: 2.21s	remaining: 25.9s
# 393:	total: 2.22s	remaining: 25.9s
# 394:	total: 2.22s	remaining: 25.9s
# 395:	total: 2.23s	remaining: 25.9s
# 396:	total: 2.23s	remaining: 25.9s
# 397:	total: 2.24s	remaining: 25.9s
# 398:	total: 2.25s	remaining: 25.9s
# 399:	total: 2.25s	remaining: 25.9s
# 400:	total: 2.26s	remaining: 25.9s
# 401:	total: 2.26s	remaining: 25.9s
# 402:	total: 2.27s	remaining: 25.9s
# 403:	total: 2.28s	remaining: 25.9s
# 404:	total: 2.28s	remaining: 25.9s
# 405:	total: 2.29s	remaining: 25.9s
# 406:	total: 2.29s	remaining: 25.9s
# 407:	total: 2.3s	remaining: 25.9s
# 408:	total: 2.31s	remaining: 25.9s
# 409:	total: 2.31s	remaining: 25.9s
# 410:	total: 2.32s	remaining: 25.9s
# 411:	total: 2.32s	remaining: 25.9s
# 412:	total: 2.33s	remaining: 25.9s
# 413:	total: 2.33s	remaining: 25.9s
# 414:	total: 2.34s	remaining: 25.8s
# 415:	total: 2.35s	remaining: 25.8s
# 416:	total: 2.35s	remaining: 25.8s
# 417:	total: 2.35s	remaining: 25.8s
# 418:	total: 2.36s	remaining: 25.8s
# 419:	total: 2.37s	remaining: 25.8s
# 420:	total: 2.37s	remaining: 25.8s
# 421:	total: 2.38s	remaining: 25.8s
# 422:	total: 2.38s	remaining: 25.8s
# 423:	total: 2.39s	remaining: 25.8s
# 424:	total: 2.39s	remaining: 25.8s
# 425:	total: 2.4s	remaining: 25.7s
# 426:	total: 2.4s	remaining: 25.7s
# 427:	total: 2.41s	remaining: 25.7s
# 428:	total: 2.41s	remaining: 25.7s
# 429:	total: 2.42s	remaining: 25.7s
# 430:	total: 2.42s	remaining: 25.7s
# 431:	total: 2.43s	remaining: 25.7s
# 432:	total: 2.43s	remaining: 25.7s
# 433:	total: 2.44s	remaining: 25.7s
# 434:	total: 2.44s	remaining: 25.7s
# 435:	total: 2.45s	remaining: 25.6s
# 436:	total: 2.46s	remaining: 25.6s
# 437:	total: 2.46s	remaining: 25.6s
# 438:	total: 2.46s	remaining: 25.6s
# 439:	total: 2.47s	remaining: 25.6s
# 440:	total: 2.48s	remaining: 25.6s
# 441:	total: 2.48s	remaining: 25.6s
# 442:	total: 2.49s	remaining: 25.6s
# 443:	total: 2.49s	remaining: 25.6s
# 444:	total: 2.5s	remaining: 25.6s
# 445:	total: 2.5s	remaining: 25.5s
# 446:	total: 2.51s	remaining: 25.5s
# 447:	total: 2.51s	remaining: 25.5s
# 448:	total: 2.52s	remaining: 25.5s
# 449:	total: 2.52s	remaining: 25.5s
# 450:	total: 2.53s	remaining: 25.5s
# 451:	total: 2.53s	remaining: 25.5s
# 452:	total: 2.54s	remaining: 25.5s
# 453:	total: 2.54s	remaining: 25.5s
# 454:	total: 2.55s	remaining: 25.5s
# 455:	total: 2.55s	remaining: 25.5s
# 456:	total: 2.56s	remaining: 25.4s
# 457:	total: 2.56s	remaining: 25.4s
# 458:	total: 2.57s	remaining: 25.4s
# 459:	total: 2.58s	remaining: 25.4s
# 460:	total: 2.58s	remaining: 25.4s
# 461:	total: 2.58s	remaining: 25.4s
# 462:	total: 2.59s	remaining: 25.4s
# 463:	total: 2.6s	remaining: 25.4s
# 464:	total: 2.6s	remaining: 25.4s
# 465:	total: 2.61s	remaining: 25.4s
# 466:	total: 2.61s	remaining: 25.3s
# 467:	total: 2.62s	remaining: 25.3s
# 468:	total: 2.62s	remaining: 25.3s
# 469:	total: 2.63s	remaining: 25.3s
# 470:	total: 2.63s	remaining: 25.3s
# 471:	total: 2.64s	remaining: 25.3s
# 472:	total: 2.64s	remaining: 25.3s
# 473:	total: 2.65s	remaining: 25.3s
# 474:	total: 2.65s	remaining: 25.3s
# 475:	total: 2.66s	remaining: 25.3s
# 476:	total: 2.66s	remaining: 25.3s
# 477:	total: 2.67s	remaining: 25.2s
# 478:	total: 2.67s	remaining: 25.2s
# 479:	total: 2.68s	remaining: 25.2s
# 480:	total: 2.68s	remaining: 25.2s
# 481:	total: 2.69s	remaining: 25.2s
# 482:	total: 2.69s	remaining: 25.2s
# 483:	total: 2.7s	remaining: 25.2s
# 484:	total: 2.7s	remaining: 25.2s
# 485:	total: 2.71s	remaining: 25.2s
# 486:	total: 2.71s	remaining: 25.2s
# 487:	total: 2.72s	remaining: 25.1s
# 488:	total: 2.73s	remaining: 25.1s
# 489:	total: 2.73s	remaining: 25.1s
# 490:	total: 2.73s	remaining: 25.1s
# 491:	total: 2.74s	remaining: 25.1s
# 492:	total: 2.75s	remaining: 25.1s
# 493:	total: 2.75s	remaining: 25.1s
# 494:	total: 2.76s	remaining: 25.1s
# 495:	total: 2.76s	remaining: 25.1s
# 496:	total: 2.77s	remaining: 25.1s
# 497:	total: 2.77s	remaining: 25.1s
# 498:	total: 2.78s	remaining: 25.1s
# 499:	total: 2.78s	remaining: 25.1s
# 500:	total: 2.79s	remaining: 25s
# 501:	total: 2.79s	remaining: 25s
# 502:	total: 2.8s	remaining: 25s
# 503:	total: 2.8s	remaining: 25s
# 504:	total: 2.81s	remaining: 25s
# 505:	total: 2.81s	remaining: 25s
# 506:	total: 2.82s	remaining: 25s
# 507:	total: 2.83s	remaining: 25s
# 508:	total: 2.83s	remaining: 25s
# 509:	total: 2.84s	remaining: 25s
# 510:	total: 2.84s	remaining: 25s
# 511:	total: 2.85s	remaining: 25s
# 512:	total: 2.85s	remaining: 25s
# 513:	total: 2.86s	remaining: 25s
# 514:	total: 2.86s	remaining: 24.9s
# 515:	total: 2.87s	remaining: 24.9s
# 516:	total: 2.87s	remaining: 24.9s
# 517:	total: 2.88s	remaining: 24.9s
# 518:	total: 2.88s	remaining: 24.9s
# 519:	total: 2.89s	remaining: 24.9s
# 520:	total: 2.9s	remaining: 24.9s
# 521:	total: 2.9s	remaining: 24.9s
# 522:	total: 2.9s	remaining: 24.9s
# 523:	total: 2.91s	remaining: 24.9s
# 524:	total: 2.92s	remaining: 24.9s
# 525:	total: 2.92s	remaining: 24.8s
# 526:	total: 2.93s	remaining: 24.8s
# 527:	total: 2.93s	remaining: 24.8s
# 528:	total: 2.94s	remaining: 24.8s
# 529:	total: 2.94s	remaining: 24.8s
# 530:	total: 2.95s	remaining: 24.8s
# 531:	total: 2.95s	remaining: 24.8s
# 532:	total: 2.96s	remaining: 24.8s
# 533:	total: 2.96s	remaining: 24.8s
# 534:	total: 2.97s	remaining: 24.8s
# 535:	total: 2.97s	remaining: 24.8s
# 536:	total: 2.98s	remaining: 24.8s
# 537:	total: 2.98s	remaining: 24.8s
# 538:	total: 2.99s	remaining: 24.7s
# 539:	total: 2.99s	remaining: 24.7s
# 540:	total: 3s	remaining: 24.7s
# 541:	total: 3.01s	remaining: 24.7s
# 542:	total: 3.01s	remaining: 24.7s
# 543:	total: 3.02s	remaining: 24.7s
# 544:	total: 3.02s	remaining: 24.7s
# 545:	total: 3.03s	remaining: 24.7s
# 546:	total: 3.03s	remaining: 24.7s
# 547:	total: 3.04s	remaining: 24.7s
# 548:	total: 3.04s	remaining: 24.7s
# 549:	total: 3.05s	remaining: 24.7s
# 550:	total: 3.05s	remaining: 24.7s
# 551:	total: 3.06s	remaining: 24.7s
# 552:	total: 3.06s	remaining: 24.6s
# 553:	total: 3.07s	remaining: 24.6s
# 554:	total: 3.07s	remaining: 24.6s
# 555:	total: 3.08s	remaining: 24.6s
# 556:	total: 3.08s	remaining: 24.6s
# 557:	total: 3.09s	remaining: 24.6s
# 558:	total: 3.1s	remaining: 24.6s
# 559:	total: 3.1s	remaining: 24.6s
# 560:	total: 3.11s	remaining: 24.6s
# 561:	total: 3.11s	remaining: 24.6s
# 562:	total: 3.12s	remaining: 24.6s
# 563:	total: 3.12s	remaining: 24.6s
# 564:	total: 3.13s	remaining: 24.5s
# 565:	total: 3.13s	remaining: 24.5s
# 566:	total: 3.14s	remaining: 24.5s
# 567:	total: 3.14s	remaining: 24.5s
# 568:	total: 3.15s	remaining: 24.5s
# 569:	total: 3.15s	remaining: 24.5s
# 570:	total: 3.16s	remaining: 24.5s
# 571:	total: 3.16s	remaining: 24.5s
# 572:	total: 3.17s	remaining: 24.5s
# 573:	total: 3.17s	remaining: 24.5s
# 574:	total: 3.18s	remaining: 24.5s
# 575:	total: 3.18s	remaining: 24.5s
# 576:	total: 3.19s	remaining: 24.5s
# 577:	total: 3.19s	remaining: 24.4s
# 578:	total: 3.2s	remaining: 24.4s
# 579:	total: 3.21s	remaining: 24.4s
# 580:	total: 3.21s	remaining: 24.4s
# 581:	total: 3.22s	remaining: 24.4s
# 582:	total: 3.22s	remaining: 24.4s
# 583:	total: 3.23s	remaining: 24.4s
# 584:	total: 3.23s	remaining: 24.4s
# 585:	total: 3.24s	remaining: 24.4s
# 586:	total: 3.25s	remaining: 24.4s
# 587:	total: 3.26s	remaining: 24.4s
# 588:	total: 3.26s	remaining: 24.4s
# 589:	total: 3.27s	remaining: 24.4s
# 590:	total: 3.28s	remaining: 24.4s
# 591:	total: 3.28s	remaining: 24.4s
# 592:	total: 3.29s	remaining: 24.4s
# 593:	total: 3.29s	remaining: 24.4s
# 594:	total: 3.3s	remaining: 24.4s
# 595:	total: 3.31s	remaining: 24.4s
# 596:	total: 3.31s	remaining: 24.4s
# 597:	total: 3.32s	remaining: 24.4s
# 598:	total: 3.33s	remaining: 24.4s
# 599:	total: 3.33s	remaining: 24.4s
# 600:	total: 3.34s	remaining: 24.4s
# 601:	total: 3.34s	remaining: 24.4s
# 602:	total: 3.35s	remaining: 24.4s
# 603:	total: 3.35s	remaining: 24.4s
# 604:	total: 3.36s	remaining: 24.4s
# 605:	total: 3.37s	remaining: 24.4s
# 606:	total: 3.37s	remaining: 24.4s
# 607:	total: 3.38s	remaining: 24.4s
# 608:	total: 3.38s	remaining: 24.4s
# 609:	total: 3.39s	remaining: 24.4s
# 610:	total: 3.4s	remaining: 24.4s
# 611:	total: 3.4s	remaining: 24.4s
# 612:	total: 3.41s	remaining: 24.4s
# 613:	total: 3.42s	remaining: 24.4s
# 614:	total: 3.42s	remaining: 24.4s
# 615:	total: 3.43s	remaining: 24.4s
# 616:	total: 3.43s	remaining: 24.4s
# 617:	total: 3.44s	remaining: 24.4s
# 618:	total: 3.44s	remaining: 24.4s
# 619:	total: 3.45s	remaining: 24.4s
# 620:	total: 3.46s	remaining: 24.4s
# 621:	total: 3.46s	remaining: 24.4s
# 622:	total: 3.47s	remaining: 24.4s
# 623:	total: 3.47s	remaining: 24.4s
# 624:	total: 3.48s	remaining: 24.4s
# 625:	total: 3.48s	remaining: 24.4s
# 626:	total: 3.49s	remaining: 24.4s
# 627:	total: 3.5s	remaining: 24.3s
# 628:	total: 3.5s	remaining: 24.3s
# 629:	total: 3.51s	remaining: 24.3s
# 630:	total: 3.51s	remaining: 24.3s
# 631:	total: 3.52s	remaining: 24.3s
# 632:	total: 3.53s	remaining: 24.3s
# 633:	total: 3.53s	remaining: 24.3s
# 634:	total: 3.54s	remaining: 24.3s
# 635:	total: 3.54s	remaining: 24.3s
# 636:	total: 3.55s	remaining: 24.3s
# 637:	total: 3.56s	remaining: 24.3s
# 638:	total: 3.56s	remaining: 24.3s
# 639:	total: 3.57s	remaining: 24.3s
# 640:	total: 3.57s	remaining: 24.3s
# 641:	total: 3.58s	remaining: 24.3s
# 642:	total: 3.58s	remaining: 24.3s
# 643:	total: 3.59s	remaining: 24.3s
# 644:	total: 3.6s	remaining: 24.3s
# 645:	total: 3.6s	remaining: 24.3s
# 646:	total: 3.61s	remaining: 24.3s
# 647:	total: 3.61s	remaining: 24.3s
# 648:	total: 3.62s	remaining: 24.3s
# 649:	total: 3.63s	remaining: 24.3s
# 650:	total: 3.63s	remaining: 24.3s
# 651:	total: 3.64s	remaining: 24.3s
# 652:	total: 3.64s	remaining: 24.3s
# 653:	total: 3.65s	remaining: 24.2s
# 654:	total: 3.65s	remaining: 24.2s
# 655:	total: 3.66s	remaining: 24.2s
# 656:	total: 3.67s	remaining: 24.2s
# 657:	total: 3.67s	remaining: 24.2s
# 658:	total: 3.68s	remaining: 24.2s
# 659:	total: 3.68s	remaining: 24.2s
# 660:	total: 3.69s	remaining: 24.2s
# 661:	total: 3.69s	remaining: 24.2s
# 662:	total: 3.7s	remaining: 24.2s
# 663:	total: 3.7s	remaining: 24.2s
# 664:	total: 3.71s	remaining: 24.2s
# 665:	total: 3.71s	remaining: 24.2s
# 666:	total: 3.72s	remaining: 24.2s
# 667:	total: 3.72s	remaining: 24.2s
# 668:	total: 3.73s	remaining: 24.1s
# 669:	total: 3.73s	remaining: 24.1s
# 670:	total: 3.74s	remaining: 24.1s
# 671:	total: 3.75s	remaining: 24.1s
# 672:	total: 3.75s	remaining: 24.1s
# 673:	total: 3.75s	remaining: 24.1s
# 674:	total: 3.76s	remaining: 24.1s
# 675:	total: 3.77s	remaining: 24.1s
# 676:	total: 3.77s	remaining: 24.1s
# 677:	total: 3.78s	remaining: 24.1s
# 678:	total: 3.78s	remaining: 24.1s
# 679:	total: 3.79s	remaining: 24.1s
# 680:	total: 3.79s	remaining: 24.1s
# 681:	total: 3.8s	remaining: 24s
# 682:	total: 3.8s	remaining: 24s
# 683:	total: 3.81s	remaining: 24s
# 684:	total: 3.81s	remaining: 24s
# 685:	total: 3.82s	remaining: 24s
# 686:	total: 3.82s	remaining: 24s
# 687:	total: 3.83s	remaining: 24s
# 688:	total: 3.83s	remaining: 24s
# 689:	total: 3.84s	remaining: 24s
# 690:	total: 3.85s	remaining: 24s
# 691:	total: 3.85s	remaining: 24s
# 692:	total: 3.86s	remaining: 24s
# 693:	total: 3.86s	remaining: 24s
# 694:	total: 3.87s	remaining: 24s
# 695:	total: 3.87s	remaining: 23.9s
# 696:	total: 3.88s	remaining: 23.9s
# 697:	total: 3.88s	remaining: 23.9s
# 698:	total: 3.89s	remaining: 23.9s
# 699:	total: 3.89s	remaining: 23.9s
# 700:	total: 3.9s	remaining: 23.9s
# 701:	total: 3.9s	remaining: 23.9s
# 702:	total: 3.91s	remaining: 23.9s
# 703:	total: 3.91s	remaining: 23.9s
# 704:	total: 3.92s	remaining: 23.9s
# 705:	total: 3.92s	remaining: 23.9s
# 706:	total: 3.93s	remaining: 23.9s
# 707:	total: 3.94s	remaining: 23.9s
# 708:	total: 3.94s	remaining: 23.9s
# 709:	total: 3.95s	remaining: 23.8s
# 710:	total: 3.95s	remaining: 23.8s
# 711:	total: 3.96s	remaining: 23.8s
# 712:	total: 3.96s	remaining: 23.8s
# 713:	total: 3.97s	remaining: 23.8s
# 714:	total: 3.97s	remaining: 23.8s
# 715:	total: 3.98s	remaining: 23.8s
# 716:	total: 3.98s	remaining: 23.8s
# 717:	total: 3.99s	remaining: 23.8s
# 718:	total: 4s	remaining: 23.8s
# 719:	total: 4s	remaining: 23.8s
# 720:	total: 4.01s	remaining: 23.8s
# 721:	total: 4.01s	remaining: 23.8s
# 722:	total: 4.02s	remaining: 23.8s
# 723:	total: 4.02s	remaining: 23.8s
# 724:	total: 4.03s	remaining: 23.8s
# 725:	total: 4.03s	remaining: 23.8s
# 726:	total: 4.04s	remaining: 23.7s
# 727:	total: 4.04s	remaining: 23.7s
# 728:	total: 4.05s	remaining: 23.7s
# 729:	total: 4.05s	remaining: 23.7s
# 730:	total: 4.06s	remaining: 23.7s
# 731:	total: 4.07s	remaining: 23.7s
# 732:	total: 4.07s	remaining: 23.7s
# 733:	total: 4.08s	remaining: 23.7s
# 734:	total: 4.08s	remaining: 23.7s
# 735:	total: 4.09s	remaining: 23.7s
# 736:	total: 4.09s	remaining: 23.7s
# 737:	total: 4.1s	remaining: 23.7s
# 738:	total: 4.1s	remaining: 23.7s
# 739:	total: 4.11s	remaining: 23.6s
# 740:	total: 4.11s	remaining: 23.6s
# 741:	total: 4.12s	remaining: 23.6s
# 742:	total: 4.12s	remaining: 23.6s
# 743:	total: 4.13s	remaining: 23.6s
# 744:	total: 4.13s	remaining: 23.6s
# 745:	total: 4.14s	remaining: 23.6s
# 746:	total: 4.14s	remaining: 23.6s
# 747:	total: 4.15s	remaining: 23.6s
# 748:	total: 4.16s	remaining: 23.6s
# 749:	total: 4.16s	remaining: 23.6s
# 750:	total: 4.17s	remaining: 23.6s
# 751:	total: 4.17s	remaining: 23.6s
# 752:	total: 4.18s	remaining: 23.6s
# 753:	total: 4.18s	remaining: 23.6s
# 754:	total: 4.19s	remaining: 23.5s
# 755:	total: 4.19s	remaining: 23.5s
# 756:	total: 4.2s	remaining: 23.5s
# 757:	total: 4.2s	remaining: 23.5s
# 758:	total: 4.21s	remaining: 23.5s
# 759:	total: 4.21s	remaining: 23.5s
# 760:	total: 4.22s	remaining: 23.5s
# 761:	total: 4.22s	remaining: 23.5s
# 762:	total: 4.23s	remaining: 23.5s
# 763:	total: 4.23s	remaining: 23.5s
# 764:	total: 4.24s	remaining: 23.5s
# 765:	total: 4.25s	remaining: 23.5s
# 766:	total: 4.25s	remaining: 23.5s
# 767:	total: 4.25s	remaining: 23.4s
# 768:	total: 4.26s	remaining: 23.4s
# 769:	total: 4.27s	remaining: 23.4s
# 770:	total: 4.27s	remaining: 23.4s
# 771:	total: 4.28s	remaining: 23.4s
# 772:	total: 4.28s	remaining: 23.4s
# 773:	total: 4.29s	remaining: 23.4s
# 774:	total: 4.29s	remaining: 23.4s
# 775:	total: 4.3s	remaining: 23.4s
# 776:	total: 4.3s	remaining: 23.4s
# 777:	total: 4.31s	remaining: 23.4s
# 778:	total: 4.31s	remaining: 23.4s
# 779:	total: 4.32s	remaining: 23.4s
# 780:	total: 4.32s	remaining: 23.4s
# 781:	total: 4.33s	remaining: 23.3s
# 782:	total: 4.33s	remaining: 23.3s
# 783:	total: 4.34s	remaining: 23.3s
# 784:	total: 4.34s	remaining: 23.3s
# 785:	total: 4.35s	remaining: 23.3s
# 786:	total: 4.35s	remaining: 23.3s
# 787:	total: 4.36s	remaining: 23.3s
# 788:	total: 4.37s	remaining: 23.3s
# 789:	total: 4.37s	remaining: 23.3s
# 790:	total: 4.38s	remaining: 23.3s
# 791:	total: 4.38s	remaining: 23.3s
# 792:	total: 4.39s	remaining: 23.3s
# 793:	total: 4.39s	remaining: 23.3s
# 794:	total: 4.4s	remaining: 23.3s
# 795:	total: 4.4s	remaining: 23.2s
# 796:	total: 4.41s	remaining: 23.2s
# 797:	total: 4.41s	remaining: 23.2s
# 798:	total: 4.42s	remaining: 23.2s
# 799:	total: 4.42s	remaining: 23.2s
# 800:	total: 4.43s	remaining: 23.2s
# 801:	total: 4.43s	remaining: 23.2s
# 802:	total: 4.44s	remaining: 23.2s
# 803:	total: 4.44s	remaining: 23.2s
# 804:	total: 4.45s	remaining: 23.2s
# 805:	total: 4.45s	remaining: 23.2s
# 806:	total: 4.46s	remaining: 23.2s
# 807:	total: 4.47s	remaining: 23.2s
# 808:	total: 4.47s	remaining: 23.2s
# 809:	total: 4.48s	remaining: 23.2s
# 810:	total: 4.48s	remaining: 23.2s
# 811:	total: 4.49s	remaining: 23.2s
# 812:	total: 4.5s	remaining: 23.2s
# 813:	total: 4.5s	remaining: 23.1s
# 814:	total: 4.51s	remaining: 23.1s
# 815:	total: 4.51s	remaining: 23.1s
# 816:	total: 4.52s	remaining: 23.1s
# 817:	total: 4.53s	remaining: 23.1s
# 818:	total: 4.53s	remaining: 23.1s
# 819:	total: 4.54s	remaining: 23.1s
# 820:	total: 4.54s	remaining: 23.1s
# 821:	total: 4.55s	remaining: 23.1s
# 822:	total: 4.55s	remaining: 23.1s
# 823:	total: 4.56s	remaining: 23.1s
# 824:	total: 4.57s	remaining: 23.1s
# 825:	total: 4.57s	remaining: 23.1s
# 826:	total: 4.58s	remaining: 23.1s
# 827:	total: 4.58s	remaining: 23.1s
# 828:	total: 4.59s	remaining: 23.1s
# 829:	total: 4.6s	remaining: 23.1s
# 830:	total: 4.6s	remaining: 23.1s
# 831:	total: 4.61s	remaining: 23.1s
# 832:	total: 4.61s	remaining: 23.1s
# 833:	total: 4.62s	remaining: 23.1s
# 834:	total: 4.63s	remaining: 23.1s
# 835:	total: 4.63s	remaining: 23.1s
# 836:	total: 4.64s	remaining: 23.1s
# 837:	total: 4.64s	remaining: 23.1s
# 838:	total: 4.65s	remaining: 23.1s
# 839:	total: 4.66s	remaining: 23.1s
# 840:	total: 4.66s	remaining: 23.1s
# 841:	total: 4.67s	remaining: 23.1s
# 842:	total: 4.67s	remaining: 23.1s
# 843:	total: 4.68s	remaining: 23.1s
# 844:	total: 4.69s	remaining: 23.1s
# 845:	total: 4.7s	remaining: 23.1s
# 846:	total: 4.7s	remaining: 23.1s
# 847:	total: 4.71s	remaining: 23.1s
# 848:	total: 4.71s	remaining: 23s
# 849:	total: 4.72s	remaining: 23s
# 850:	total: 4.73s	remaining: 23s
# 851:	total: 4.73s	remaining: 23s
# 852:	total: 4.74s	remaining: 23s
# 853:	total: 4.75s	remaining: 23s
# 854:	total: 4.75s	remaining: 23s
# 855:	total: 4.76s	remaining: 23s
# 856:	total: 4.77s	remaining: 23s
# 857:	total: 4.77s	remaining: 23s
# 858:	total: 4.78s	remaining: 23s
# 859:	total: 4.79s	remaining: 23s
# 860:	total: 4.79s	remaining: 23s
# 861:	total: 4.8s	remaining: 23s
# 862:	total: 4.8s	remaining: 23s
# 863:	total: 4.81s	remaining: 23s
# 864:	total: 4.82s	remaining: 23s
# 865:	total: 4.82s	remaining: 23s
# 866:	total: 4.83s	remaining: 23s
# 867:	total: 4.84s	remaining: 23s
# 868:	total: 4.84s	remaining: 23s
# 869:	total: 4.85s	remaining: 23s
# 870:	total: 4.86s	remaining: 23s
# 871:	total: 4.86s	remaining: 23s
# 872:	total: 4.87s	remaining: 23s
# 873:	total: 4.88s	remaining: 23s
# 874:	total: 4.88s	remaining: 23s
# 875:	total: 4.89s	remaining: 23s
# 876:	total: 4.89s	remaining: 23s
# 877:	total: 4.9s	remaining: 23s
# 878:	total: 4.91s	remaining: 23s
# 879:	total: 4.91s	remaining: 23s
# 880:	total: 4.92s	remaining: 23s
# 881:	total: 4.93s	remaining: 23s
# 882:	total: 4.93s	remaining: 23s
# 883:	total: 4.94s	remaining: 23s
# 884:	total: 4.94s	remaining: 23s
# 885:	total: 4.95s	remaining: 23s
# 886:	total: 4.96s	remaining: 23s
# 887:	total: 4.96s	remaining: 23s
# 888:	total: 4.97s	remaining: 23s
# 889:	total: 4.97s	remaining: 23s
# 890:	total: 4.98s	remaining: 23s
# 891:	total: 4.99s	remaining: 23s
# 892:	total: 4.99s	remaining: 22.9s
# 893:	total: 5s	remaining: 22.9s
# 894:	total: 5s	remaining: 22.9s
# 895:	total: 5s	remaining: 22.9s
# 896:	total: 5.01s	remaining: 22.9s
# 897:	total: 5.02s	remaining: 22.9s
# 898:	total: 5.02s	remaining: 22.9s
# 899:	total: 5.03s	remaining: 22.9s
# 900:	total: 5.03s	remaining: 22.9s
# 901:	total: 5.04s	remaining: 22.9s
# 902:	total: 5.04s	remaining: 22.9s
# 903:	total: 5.05s	remaining: 22.9s
# 904:	total: 5.05s	remaining: 22.9s
# 905:	total: 5.06s	remaining: 22.9s
# 906:	total: 5.07s	remaining: 22.9s
# 907:	total: 5.07s	remaining: 22.9s
# 908:	total: 5.08s	remaining: 22.8s
# 909:	total: 5.08s	remaining: 22.8s
# 910:	total: 5.09s	remaining: 22.8s
# 911:	total: 5.09s	remaining: 22.8s
# 912:	total: 5.1s	remaining: 22.8s
# 913:	total: 5.1s	remaining: 22.8s
# 914:	total: 5.11s	remaining: 22.8s
# 915:	total: 5.12s	remaining: 22.8s
# 916:	total: 5.12s	remaining: 22.8s
# 917:	total: 5.13s	remaining: 22.8s
# 918:	total: 5.13s	remaining: 22.8s
# 919:	total: 5.14s	remaining: 22.8s
# 920:	total: 5.14s	remaining: 22.8s
# 921:	total: 5.15s	remaining: 22.8s
# 922:	total: 5.16s	remaining: 22.8s
# 923:	total: 5.16s	remaining: 22.8s
# 924:	total: 5.17s	remaining: 22.8s
# 925:	total: 5.17s	remaining: 22.8s
# 926:	total: 5.18s	remaining: 22.8s
# 927:	total: 5.19s	remaining: 22.8s
# 928:	total: 5.19s	remaining: 22.8s
# 929:	total: 5.2s	remaining: 22.8s
# 930:	total: 5.2s	remaining: 22.7s
# 931:	total: 5.21s	remaining: 22.7s
# 932:	total: 5.22s	remaining: 22.7s
# 933:	total: 5.22s	remaining: 22.7s
# 934:	total: 5.23s	remaining: 22.7s
# 935:	total: 5.23s	remaining: 22.7s
# 936:	total: 5.24s	remaining: 22.7s
# 937:	total: 5.24s	remaining: 22.7s
# 938:	total: 5.25s	remaining: 22.7s
# 939:	total: 5.25s	remaining: 22.7s
# 940:	total: 5.26s	remaining: 22.7s
# 941:	total: 5.26s	remaining: 22.7s
# 942:	total: 5.27s	remaining: 22.7s
# 943:	total: 5.27s	remaining: 22.7s
# 944:	total: 5.28s	remaining: 22.7s
# 945:	total: 5.28s	remaining: 22.6s
# 946:	total: 5.29s	remaining: 22.6s
# 947:	total: 5.29s	remaining: 22.6s
# 948:	total: 5.3s	remaining: 22.6s
# 949:	total: 5.3s	remaining: 22.6s
# 950:	total: 5.31s	remaining: 22.6s
# 951:	total: 5.32s	remaining: 22.6s
# 952:	total: 5.32s	remaining: 22.6s
# 953:	total: 5.33s	remaining: 22.6s
# 954:	total: 5.33s	remaining: 22.6s
# 955:	total: 5.34s	remaining: 22.6s
# 956:	total: 5.34s	remaining: 22.6s
# 957:	total: 5.35s	remaining: 22.6s
# 958:	total: 5.35s	remaining: 22.6s
# 959:	total: 5.36s	remaining: 22.5s
# 960:	total: 5.36s	remaining: 22.5s
# 961:	total: 5.37s	remaining: 22.5s
# 962:	total: 5.37s	remaining: 22.5s
# 963:	total: 5.38s	remaining: 22.5s
# 964:	total: 5.38s	remaining: 22.5s
# 965:	total: 5.39s	remaining: 22.5s
# 966:	total: 5.39s	remaining: 22.5s
# 967:	total: 5.4s	remaining: 22.5s
# 968:	total: 5.4s	remaining: 22.5s
# 969:	total: 5.41s	remaining: 22.5s
# 970:	total: 5.41s	remaining: 22.5s
# 971:	total: 5.42s	remaining: 22.5s
# 972:	total: 5.42s	remaining: 22.5s
# 973:	total: 5.43s	remaining: 22.4s
# 974:	total: 5.43s	remaining: 22.4s
# 975:	total: 5.44s	remaining: 22.4s
# 976:	total: 5.45s	remaining: 22.4s
# 977:	total: 5.45s	remaining: 22.4s
# 978:	total: 5.46s	remaining: 22.4s
# 979:	total: 5.46s	remaining: 22.4s
# 980:	total: 5.47s	remaining: 22.4s
# 981:	total: 5.47s	remaining: 22.4s
# 982:	total: 5.48s	remaining: 22.4s
# 983:	total: 5.48s	remaining: 22.4s
# 984:	total: 5.49s	remaining: 22.4s
# 985:	total: 5.49s	remaining: 22.4s
# 986:	total: 5.5s	remaining: 22.4s
# 987:	total: 5.5s	remaining: 22.3s
# 988:	total: 5.51s	remaining: 22.3s
# 989:	total: 5.51s	remaining: 22.3s
# 990:	total: 5.52s	remaining: 22.3s
# 991:	total: 5.52s	remaining: 22.3s
# 992:	total: 5.53s	remaining: 22.3s
# 993:	total: 5.54s	remaining: 22.3s
# 994:	total: 5.54s	remaining: 22.3s
# 995:	total: 5.54s	remaining: 22.3s
# 996:	total: 5.55s	remaining: 22.3s
# 997:	total: 5.56s	remaining: 22.3s
# 998:	total: 5.56s	remaining: 22.3s
# 999:	total: 5.57s	remaining: 22.3s
# 1000:	total: 5.57s	remaining: 22.3s
# 1001:	total: 5.58s	remaining: 22.3s
# 1002:	total: 5.58s	remaining: 22.2s
# 1003:	total: 5.59s	remaining: 22.2s
# 1004:	total: 5.59s	remaining: 22.2s
# 1005:	total: 5.6s	remaining: 22.2s
# 1006:	total: 5.6s	remaining: 22.2s
# 1007:	total: 5.61s	remaining: 22.2s
# 1008:	total: 5.61s	remaining: 22.2s
# 1009:	total: 5.62s	remaining: 22.2s
# 1010:	total: 5.63s	remaining: 22.2s
# 1011:	total: 5.63s	remaining: 22.2s
# 1012:	total: 5.64s	remaining: 22.2s
# 1013:	total: 5.64s	remaining: 22.2s
# 1014:	total: 5.65s	remaining: 22.2s
# 1015:	total: 5.65s	remaining: 22.2s
# 1016:	total: 5.66s	remaining: 22.2s
# 1017:	total: 5.66s	remaining: 22.1s
# 1018:	total: 5.67s	remaining: 22.1s
# 1019:	total: 5.67s	remaining: 22.1s
# 1020:	total: 5.68s	remaining: 22.1s
# 1021:	total: 5.68s	remaining: 22.1s
# 1022:	total: 5.69s	remaining: 22.1s
# 1023:	total: 5.7s	remaining: 22.1s
# 1024:	total: 5.7s	remaining: 22.1s
# 1025:	total: 5.71s	remaining: 22.1s
# 1026:	total: 5.71s	remaining: 22.1s
# 1027:	total: 5.72s	remaining: 22.1s
# 1028:	total: 5.72s	remaining: 22.1s
# 1029:	total: 5.73s	remaining: 22.1s
# 1030:	total: 5.73s	remaining: 22.1s
# 1031:	total: 5.74s	remaining: 22.1s
# 1032:	total: 5.74s	remaining: 22.1s
# 1033:	total: 5.75s	remaining: 22s
# 1034:	total: 5.75s	remaining: 22s
# 1035:	total: 5.76s	remaining: 22s
# 1036:	total: 5.77s	remaining: 22s
# 1037:	total: 5.77s	remaining: 22s
# 1038:	total: 5.78s	remaining: 22s
# 1039:	total: 5.79s	remaining: 22s
# 1040:	total: 5.79s	remaining: 22s
# 1041:	total: 5.8s	remaining: 22s
# 1042:	total: 5.81s	remaining: 22s
# 1043:	total: 5.81s	remaining: 22s
# 1044:	total: 5.82s	remaining: 22s
# 1045:	total: 5.83s	remaining: 22s
# 1046:	total: 5.83s	remaining: 22s
# 1047:	total: 5.84s	remaining: 22s
# 1048:	total: 5.84s	remaining: 22s
# 1049:	total: 5.85s	remaining: 22s
# 1050:	total: 5.86s	remaining: 22s
# 1051:	total: 5.86s	remaining: 22s
# 1052:	total: 5.87s	remaining: 22s
# 1053:	total: 5.88s	remaining: 22s
# 1054:	total: 5.88s	remaining: 22s
# 1055:	total: 5.89s	remaining: 22s
# 1056:	total: 5.89s	remaining: 22s
# 1057:	total: 5.9s	remaining: 22s
# 1058:	total: 5.9s	remaining: 22s
# 1059:	total: 5.91s	remaining: 22s
# 1060:	total: 5.91s	remaining: 22s
# 1061:	total: 5.92s	remaining: 22s
# 1062:	total: 5.93s	remaining: 21.9s
# 1063:	total: 5.93s	remaining: 21.9s
# 1064:	total: 5.94s	remaining: 21.9s
# 1065:	total: 5.94s	remaining: 21.9s
# 1066:	total: 5.95s	remaining: 21.9s
# 1067:	total: 5.95s	remaining: 21.9s
# 1068:	total: 5.96s	remaining: 21.9s
# 1069:	total: 5.96s	remaining: 21.9s
# 1070:	total: 5.97s	remaining: 21.9s
# 1071:	total: 5.98s	remaining: 21.9s
# 1072:	total: 5.98s	remaining: 21.9s
# 1073:	total: 5.99s	remaining: 21.9s
# 1074:	total: 5.99s	remaining: 21.9s
# 1075:	total: 6s	remaining: 21.9s
# 1076:	total: 6s	remaining: 21.9s
# 1077:	total: 6.01s	remaining: 21.9s
# 1078:	total: 6.02s	remaining: 21.9s
# 1079:	total: 6.02s	remaining: 21.9s
# 1080:	total: 6.03s	remaining: 21.9s
# 1081:	total: 6.03s	remaining: 21.8s
# 1082:	total: 6.04s	remaining: 21.8s
# 1083:	total: 6.04s	remaining: 21.8s
# 1084:	total: 6.05s	remaining: 21.8s
# 1085:	total: 6.06s	remaining: 21.8s
# 1086:	total: 6.06s	remaining: 21.8s
# 1087:	total: 6.07s	remaining: 21.8s
# 1088:	total: 6.07s	remaining: 21.8s
# 1089:	total: 6.08s	remaining: 21.8s
# 1090:	total: 6.08s	remaining: 21.8s
# 1091:	total: 6.09s	remaining: 21.8s
# 1092:	total: 6.09s	remaining: 21.8s
# 1093:	total: 6.1s	remaining: 21.8s
# 1094:	total: 6.11s	remaining: 21.8s
# 1095:	total: 6.11s	remaining: 21.8s
# 1096:	total: 6.12s	remaining: 21.8s
# 1097:	total: 6.12s	remaining: 21.8s
# 1098:	total: 6.13s	remaining: 21.8s
# 1099:	total: 6.13s	remaining: 21.7s
# 1100:	total: 6.14s	remaining: 21.7s
# 1101:	total: 6.14s	remaining: 21.7s
# 1102:	total: 6.15s	remaining: 21.7s
# 1103:	total: 6.16s	remaining: 21.7s
# 1104:	total: 6.16s	remaining: 21.7s
# 1105:	total: 6.17s	remaining: 21.7s
# 1106:	total: 6.17s	remaining: 21.7s
# 1107:	total: 6.18s	remaining: 21.7s
# 1108:	total: 6.18s	remaining: 21.7s
# 1109:	total: 6.19s	remaining: 21.7s
# 1110:	total: 6.2s	remaining: 21.7s
# 1111:	total: 6.2s	remaining: 21.7s
# 1112:	total: 6.21s	remaining: 21.7s
# 1113:	total: 6.21s	remaining: 21.7s
# 1114:	total: 6.22s	remaining: 21.7s
# 1115:	total: 6.22s	remaining: 21.7s
# 1116:	total: 6.23s	remaining: 21.7s
# 1117:	total: 6.23s	remaining: 21.6s
# 1118:	total: 6.24s	remaining: 21.6s
# 1119:	total: 6.25s	remaining: 21.6s
# 1120:	total: 6.25s	remaining: 21.6s
# 1121:	total: 6.26s	remaining: 21.6s
# 1122:	total: 6.26s	remaining: 21.6s
# 1123:	total: 6.27s	remaining: 21.6s
# 1124:	total: 6.27s	remaining: 21.6s
# 1125:	total: 6.28s	remaining: 21.6s
# 1126:	total: 6.28s	remaining: 21.6s
# 1127:	total: 6.29s	remaining: 21.6s
# 1128:	total: 6.29s	remaining: 21.6s
# 1129:	total: 6.3s	remaining: 21.6s
# 1130:	total: 6.31s	remaining: 21.6s
# 1131:	total: 6.31s	remaining: 21.6s
# 1132:	total: 6.32s	remaining: 21.6s
# 1133:	total: 6.32s	remaining: 21.6s
# 1134:	total: 6.33s	remaining: 21.5s
# 1135:	total: 6.33s	remaining: 21.5s
# 1136:	total: 6.34s	remaining: 21.5s
# 1137:	total: 6.34s	remaining: 21.5s
# 1138:	total: 6.35s	remaining: 21.5s
# 1139:	total: 6.36s	remaining: 21.5s
# 1140:	total: 6.36s	remaining: 21.5s
# 1141:	total: 6.37s	remaining: 21.5s
# 1142:	total: 6.37s	remaining: 21.5s
# 1143:	total: 6.38s	remaining: 21.5s
# 1144:	total: 6.38s	remaining: 21.5s
# 1145:	total: 6.39s	remaining: 21.5s
# 1146:	total: 6.39s	remaining: 21.5s
# 1147:	total: 6.4s	remaining: 21.5s
# 1148:	total: 6.41s	remaining: 21.5s
# 1149:	total: 6.41s	remaining: 21.5s
# 1150:	total: 6.42s	remaining: 21.5s
# 1151:	total: 6.42s	remaining: 21.5s
# 1152:	total: 6.43s	remaining: 21.4s
# 1153:	total: 6.43s	remaining: 21.4s
# 1154:	total: 6.44s	remaining: 21.4s
# 1155:	total: 6.44s	remaining: 21.4s
# 1156:	total: 6.45s	remaining: 21.4s
# 1157:	total: 6.46s	remaining: 21.4s
# 1158:	total: 6.46s	remaining: 21.4s
# 1159:	total: 6.47s	remaining: 21.4s
# 1160:	total: 6.47s	remaining: 21.4s
# 1161:	total: 6.48s	remaining: 21.4s
# 1162:	total: 6.48s	remaining: 21.4s
# 1163:	total: 6.49s	remaining: 21.4s
# 1164:	total: 6.5s	remaining: 21.4s
# 1165:	total: 6.5s	remaining: 21.4s
# 1166:	total: 6.51s	remaining: 21.4s
# 1167:	total: 6.51s	remaining: 21.4s
# 1168:	total: 6.52s	remaining: 21.4s
# 1169:	total: 6.52s	remaining: 21.4s
# 1170:	total: 6.53s	remaining: 21.3s
# 1171:	total: 6.53s	remaining: 21.3s
# 1172:	total: 6.54s	remaining: 21.3s
# 1173:	total: 6.54s	remaining: 21.3s
# 1174:	total: 6.55s	remaining: 21.3s
# 1175:	total: 6.56s	remaining: 21.3s
# 1176:	total: 6.56s	remaining: 21.3s
# 1177:	total: 6.57s	remaining: 21.3s
# 1178:	total: 6.57s	remaining: 21.3s
# 1179:	total: 6.58s	remaining: 21.3s
# 1180:	total: 6.58s	remaining: 21.3s
# 1181:	total: 6.59s	remaining: 21.3s
# 1182:	total: 6.59s	remaining: 21.3s
# 1183:	total: 6.6s	remaining: 21.3s
# 1184:	total: 6.61s	remaining: 21.3s
# 1185:	total: 6.61s	remaining: 21.3s
# 1186:	total: 6.62s	remaining: 21.3s
# 1187:	total: 6.62s	remaining: 21.2s
# 1188:	total: 6.63s	remaining: 21.2s
# 1189:	total: 6.63s	remaining: 21.2s
# 1190:	total: 6.64s	remaining: 21.2s
# 1191:	total: 6.64s	remaining: 21.2s
# 1192:	total: 6.65s	remaining: 21.2s
# 1193:	total: 6.66s	remaining: 21.2s
# 1194:	total: 6.66s	remaining: 21.2s
# 1195:	total: 6.67s	remaining: 21.2s
# 1196:	total: 6.67s	remaining: 21.2s
# 1197:	total: 6.68s	remaining: 21.2s
# 1198:	total: 6.68s	remaining: 21.2s
# 1199:	total: 6.69s	remaining: 21.2s
# 1200:	total: 6.69s	remaining: 21.2s
# 1201:	total: 6.7s	remaining: 21.2s
# 1202:	total: 6.71s	remaining: 21.2s
# 1203:	total: 6.71s	remaining: 21.2s
# 1204:	total: 6.72s	remaining: 21.2s
# 1205:	total: 6.72s	remaining: 21.1s
# 1206:	total: 6.73s	remaining: 21.1s
# 1207:	total: 6.73s	remaining: 21.1s
# 1208:	total: 6.74s	remaining: 21.1s
# 1209:	total: 6.74s	remaining: 21.1s
# 1210:	total: 6.75s	remaining: 21.1s
# 1211:	total: 6.75s	remaining: 21.1s
# 1212:	total: 6.76s	remaining: 21.1s
# 1213:	total: 6.77s	remaining: 21.1s
# 1214:	total: 6.77s	remaining: 21.1s
# 1215:	total: 6.78s	remaining: 21.1s
# 1216:	total: 6.78s	remaining: 21.1s
# 1217:	total: 6.79s	remaining: 21.1s
# 1218:	total: 6.79s	remaining: 21.1s
# 1219:	total: 6.8s	remaining: 21.1s
# 1220:	total: 6.8s	remaining: 21.1s
# 1221:	total: 6.81s	remaining: 21.1s
# 1222:	total: 6.82s	remaining: 21.1s
# 1223:	total: 6.82s	remaining: 21s
# 1224:	total: 6.83s	remaining: 21s
# 1225:	total: 6.83s	remaining: 21s
# 1226:	total: 6.84s	remaining: 21s
# 1227:	total: 6.84s	remaining: 21s
# 1228:	total: 6.85s	remaining: 21s
# 1229:	total: 6.85s	remaining: 21s
# 1230:	total: 6.86s	remaining: 21s
# 1231:	total: 6.87s	remaining: 21s
# 1232:	total: 6.87s	remaining: 21s
# 1233:	total: 6.88s	remaining: 21s
# 1234:	total: 6.88s	remaining: 21s
# 1235:	total: 6.89s	remaining: 21s
# 1236:	total: 6.89s	remaining: 21s
# 1237:	total: 6.9s	remaining: 21s
# 1238:	total: 6.91s	remaining: 21s
# 1239:	total: 6.91s	remaining: 21s
# 1240:	total: 6.92s	remaining: 20.9s
# 1241:	total: 6.92s	remaining: 20.9s
# 1242:	total: 6.93s	remaining: 20.9s
# 1243:	total: 6.93s	remaining: 20.9s
# 1244:	total: 6.94s	remaining: 20.9s
# 1245:	total: 6.94s	remaining: 20.9s
# 1246:	total: 6.95s	remaining: 20.9s
# 1247:	total: 6.96s	remaining: 20.9s
# 1248:	total: 6.96s	remaining: 20.9s
# 1249:	total: 6.97s	remaining: 20.9s
# 1250:	total: 6.97s	remaining: 20.9s
# 1251:	total: 6.98s	remaining: 20.9s
# 1252:	total: 6.98s	remaining: 20.9s
# 1253:	total: 6.99s	remaining: 20.9s
# 1254:	total: 6.99s	remaining: 20.9s
# 1255:	total: 7s	remaining: 20.9s
# 1256:	total: 7s	remaining: 20.9s
# 1257:	total: 7.01s	remaining: 20.9s
# 1258:	total: 7.02s	remaining: 20.8s
# 1259:	total: 7.02s	remaining: 20.8s
# 1260:	total: 7.03s	remaining: 20.8s
# 1261:	total: 7.03s	remaining: 20.8s
# 1262:	total: 7.04s	remaining: 20.8s
# 1263:	total: 7.04s	remaining: 20.8s
# 1264:	total: 7.05s	remaining: 20.8s
# 1265:	total: 7.05s	remaining: 20.8s
# 1266:	total: 7.06s	remaining: 20.8s
# 1267:	total: 7.07s	remaining: 20.8s
# 1268:	total: 7.07s	remaining: 20.8s
# 1269:	total: 7.08s	remaining: 20.8s
# 1270:	total: 7.08s	remaining: 20.8s
# 1271:	total: 7.09s	remaining: 20.8s
# 1272:	total: 7.09s	remaining: 20.8s
# 1273:	total: 7.1s	remaining: 20.8s
# 1274:	total: 7.11s	remaining: 20.8s
# 1275:	total: 7.11s	remaining: 20.8s
# 1276:	total: 7.12s	remaining: 20.7s
# 1277:	total: 7.12s	remaining: 20.7s
# 1278:	total: 7.13s	remaining: 20.7s
# 1279:	total: 7.13s	remaining: 20.7s
# 1280:	total: 7.14s	remaining: 20.7s
# 1281:	total: 7.14s	remaining: 20.7s
# 1282:	total: 7.15s	remaining: 20.7s
# 1283:	total: 7.16s	remaining: 20.7s
# 1284:	total: 7.16s	remaining: 20.7s
# 1285:	total: 7.17s	remaining: 20.7s
# 1286:	total: 7.17s	remaining: 20.7s
# 1287:	total: 7.18s	remaining: 20.7s
# 1288:	total: 7.18s	remaining: 20.7s
# 1289:	total: 7.19s	remaining: 20.7s
# 1290:	total: 7.2s	remaining: 20.7s
# 1291:	total: 7.2s	remaining: 20.7s
# 1292:	total: 7.21s	remaining: 20.7s
# 1293:	total: 7.21s	remaining: 20.7s
# 1294:	total: 7.22s	remaining: 20.6s
# 1295:	total: 7.22s	remaining: 20.6s
# 1296:	total: 7.23s	remaining: 20.6s
# 1297:	total: 7.23s	remaining: 20.6s
# 1298:	total: 7.24s	remaining: 20.6s
# 1299:	total: 7.25s	remaining: 20.6s
# 1300:	total: 7.25s	remaining: 20.6s
# 1301:	total: 7.26s	remaining: 20.6s
# 1302:	total: 7.26s	remaining: 20.6s
# 1303:	total: 7.27s	remaining: 20.6s
# 1304:	total: 7.27s	remaining: 20.6s
# 1305:	total: 7.28s	remaining: 20.6s
# 1306:	total: 7.28s	remaining: 20.6s
# 1307:	total: 7.29s	remaining: 20.6s
# 1308:	total: 7.29s	remaining: 20.6s
# 1309:	total: 7.3s	remaining: 20.6s
# 1310:	total: 7.31s	remaining: 20.6s
# 1311:	total: 7.31s	remaining: 20.6s
# 1312:	total: 7.32s	remaining: 20.5s
# 1313:	total: 7.32s	remaining: 20.5s
# 1314:	total: 7.33s	remaining: 20.5s
# 1315:	total: 7.33s	remaining: 20.5s
# 1316:	total: 7.34s	remaining: 20.5s
# 1317:	total: 7.35s	remaining: 20.5s
# 1318:	total: 7.35s	remaining: 20.5s
# 1319:	total: 7.36s	remaining: 20.5s
# 1320:	total: 7.36s	remaining: 20.5s
# 1321:	total: 7.37s	remaining: 20.5s
# 1322:	total: 7.38s	remaining: 20.5s
# 1323:	total: 7.38s	remaining: 20.5s
# 1324:	total: 7.39s	remaining: 20.5s
# 1325:	total: 7.39s	remaining: 20.5s
# 1326:	total: 7.4s	remaining: 20.5s
# 1327:	total: 7.4s	remaining: 20.5s
# 1328:	total: 7.41s	remaining: 20.5s
# 1329:	total: 7.42s	remaining: 20.5s
# 1330:	total: 7.42s	remaining: 20.5s
# 1331:	total: 7.43s	remaining: 20.5s
# 1332:	total: 7.43s	remaining: 20.5s
# 1333:	total: 7.44s	remaining: 20.4s
# 1334:	total: 7.45s	remaining: 20.4s
# 1335:	total: 7.45s	remaining: 20.4s
# 1336:	total: 7.46s	remaining: 20.4s
# 1337:	total: 7.46s	remaining: 20.4s
# 1338:	total: 7.47s	remaining: 20.4s
# 1339:	total: 7.47s	remaining: 20.4s
# 1340:	total: 7.48s	remaining: 20.4s
# 1341:	total: 7.49s	remaining: 20.4s
# 1342:	total: 7.49s	remaining: 20.4s
# 1343:	total: 7.5s	remaining: 20.4s
# 1344:	total: 7.5s	remaining: 20.4s
# 1345:	total: 7.51s	remaining: 20.4s
# 1346:	total: 7.52s	remaining: 20.4s
# 1347:	total: 7.52s	remaining: 20.4s
# 1348:	total: 7.53s	remaining: 20.4s
# 1349:	total: 7.53s	remaining: 20.4s
# 1350:	total: 7.54s	remaining: 20.4s
# 1351:	total: 7.54s	remaining: 20.4s
# 1352:	total: 7.55s	remaining: 20.4s
# 1353:	total: 7.56s	remaining: 20.3s
# 1354:	total: 7.56s	remaining: 20.3s
# 1355:	total: 7.57s	remaining: 20.3s
# 1356:	total: 7.57s	remaining: 20.3s
# 1357:	total: 7.58s	remaining: 20.3s
# 1358:	total: 7.58s	remaining: 20.3s
# 1359:	total: 7.59s	remaining: 20.3s
# 1360:	total: 7.59s	remaining: 20.3s
# 1361:	total: 7.6s	remaining: 20.3s
# 1362:	total: 7.6s	remaining: 20.3s
# 1363:	total: 7.61s	remaining: 20.3s
# 1364:	total: 7.61s	remaining: 20.3s
# 1365:	total: 7.62s	remaining: 20.3s
# 1366:	total: 7.63s	remaining: 20.3s
# 1367:	total: 7.63s	remaining: 20.3s
# 1368:	total: 7.64s	remaining: 20.3s
# 1369:	total: 7.64s	remaining: 20.2s
# 1370:	total: 7.65s	remaining: 20.2s
# 1371:	total: 7.65s	remaining: 20.2s
# 1372:	total: 7.66s	remaining: 20.2s
# 1373:	total: 7.66s	remaining: 20.2s
# 1374:	total: 7.67s	remaining: 20.2s
# 1375:	total: 7.67s	remaining: 20.2s
# 1376:	total: 7.68s	remaining: 20.2s
# 1377:	total: 7.68s	remaining: 20.2s
# 1378:	total: 7.69s	remaining: 20.2s
# 1379:	total: 7.69s	remaining: 20.2s
# 1380:	total: 7.7s	remaining: 20.2s
# ...
# 4571:	total: 25.1s	remaining: 2.35s
# 4572:	total: 25.1s	remaining: 2.35s
# 4573:	total: 25.1s	remaining: 2.34s
# 4574:	total: 25.1s	remaining: 2.33s
# 4575:	total: 25.1s	remaining: 2.33s
# 4576:	total: 25.1s	remaining: 2.32s
# 4577:	total: 25.1s	remaining: 2.32s
# 4578:	total: 25.1s	remaining: 2.31s
# 4579:	total: 25.2s	remaining: 2.31s
# 4580:	total: 25.2s	remaining: 2.3s
# 4581:	total: 25.2s	remaining: 2.29s
# 4582:	total: 25.2s	remaining: 2.29s
# 4583:	total: 25.2s	remaining: 2.28s
# 4584:	total: 25.2s	remaining: 2.28s
# 4585:	total: 25.2s	remaining: 2.27s
# 4586:	total: 25.2s	remaining: 2.27s
# 4587:	total: 25.2s	remaining: 2.26s
# 4588:	total: 25.2s	remaining: 2.26s
# 4589:	total: 25.2s	remaining: 2.25s
# 4590:	total: 25.2s	remaining: 2.25s
# 4591:	total: 25.2s	remaining: 2.24s
# 4592:	total: 25.2s	remaining: 2.23s
# 4593:	total: 25.2s	remaining: 2.23s
# 4594:	total: 25.2s	remaining: 2.22s
# 4595:	total: 25.2s	remaining: 2.22s
# 4596:	total: 25.2s	remaining: 2.21s
# 4597:	total: 25.2s	remaining: 2.21s
# 4598:	total: 25.3s	remaining: 2.2s
# 4599:	total: 25.3s	remaining: 2.2s
# 4600:	total: 25.3s	remaining: 2.19s
# 4601:	total: 25.3s	remaining: 2.19s
# 4602:	total: 25.3s	remaining: 2.18s
# 4603:	total: 25.3s	remaining: 2.17s
# 4604:	total: 25.3s	remaining: 2.17s
# 4605:	total: 25.3s	remaining: 2.16s
# 4606:	total: 25.3s	remaining: 2.16s
# 4607:	total: 25.3s	remaining: 2.15s
# 4608:	total: 25.3s	remaining: 2.15s
# 4609:	total: 25.3s	remaining: 2.14s
# 4610:	total: 25.3s	remaining: 2.13s
# 4611:	total: 25.3s	remaining: 2.13s
# 4612:	total: 25.3s	remaining: 2.12s
# 4613:	total: 25.3s	remaining: 2.12s
# 4614:	total: 25.3s	remaining: 2.11s
# 4615:	total: 25.3s	remaining: 2.11s
# 4616:	total: 25.4s	remaining: 2.1s
# 4617:	total: 25.4s	remaining: 2.1s
# 4618:	total: 25.4s	remaining: 2.09s
# 4619:	total: 25.4s	remaining: 2.09s
# 4620:	total: 25.4s	remaining: 2.08s
# 4621:	total: 25.4s	remaining: 2.08s
# 4622:	total: 25.4s	remaining: 2.07s
# 4623:	total: 25.4s	remaining: 2.06s
# 4624:	total: 25.4s	remaining: 2.06s
# 4625:	total: 25.4s	remaining: 2.05s
# 4626:	total: 25.4s	remaining: 2.05s
# 4627:	total: 25.4s	remaining: 2.04s
# 4628:	total: 25.4s	remaining: 2.04s
# 4629:	total: 25.4s	remaining: 2.03s
# 4630:	total: 25.4s	remaining: 2.03s
# 4631:	total: 25.4s	remaining: 2.02s
# 4632:	total: 25.4s	remaining: 2.02s
# 4633:	total: 25.4s	remaining: 2.01s
# 4634:	total: 25.4s	remaining: 2s
# 4635:	total: 25.5s	remaining: 2s
# 4636:	total: 25.5s	remaining: 1.99s
# 4637:	total: 25.5s	remaining: 1.99s
# 4638:	total: 25.5s	remaining: 1.98s
# 4639:	total: 25.5s	remaining: 1.98s
# 4640:	total: 25.5s	remaining: 1.97s
# 4641:	total: 25.5s	remaining: 1.97s
# 4642:	total: 25.5s	remaining: 1.96s
# 4643:	total: 25.5s	remaining: 1.95s
# 4644:	total: 25.5s	remaining: 1.95s
# 4645:	total: 25.5s	remaining: 1.94s
# 4646:	total: 25.5s	remaining: 1.94s
# 4647:	total: 25.5s	remaining: 1.93s
# 4648:	total: 25.5s	remaining: 1.93s
# 4649:	total: 25.5s	remaining: 1.92s
# 4650:	total: 25.5s	remaining: 1.92s
# 4651:	total: 25.5s	remaining: 1.91s
# 4652:	total: 25.5s	remaining: 1.91s
# 4653:	total: 25.6s	remaining: 1.9s
# 4654:	total: 25.6s	remaining: 1.89s
# 4655:	total: 25.6s	remaining: 1.89s
# 4656:	total: 25.6s	remaining: 1.88s
# 4657:	total: 25.6s	remaining: 1.88s
# 4658:	total: 25.6s	remaining: 1.87s
# 4659:	total: 25.6s	remaining: 1.87s
# 4660:	total: 25.6s	remaining: 1.86s
# 4661:	total: 25.6s	remaining: 1.85s
# 4662:	total: 25.6s	remaining: 1.85s
# 4663:	total: 25.6s	remaining: 1.84s
# 4664:	total: 25.6s	remaining: 1.84s
# 4665:	total: 25.6s	remaining: 1.83s
# 4666:	total: 25.6s	remaining: 1.83s
# 4667:	total: 25.6s	remaining: 1.82s
# 4668:	total: 25.6s	remaining: 1.82s
# 4669:	total: 25.6s	remaining: 1.81s
# 4670:	total: 25.6s	remaining: 1.81s
# 4671:	total: 25.7s	remaining: 1.8s
# 4672:	total: 25.7s	remaining: 1.79s
# 4673:	total: 25.7s	remaining: 1.79s
# 4674:	total: 25.7s	remaining: 1.78s
# 4675:	total: 25.7s	remaining: 1.78s
# 4676:	total: 25.7s	remaining: 1.77s
# 4677:	total: 25.7s	remaining: 1.77s
# 4678:	total: 25.7s	remaining: 1.76s
# 4679:	total: 25.7s	remaining: 1.76s
# 4680:	total: 25.7s	remaining: 1.75s
# 4681:	total: 25.7s	remaining: 1.75s
# 4682:	total: 25.7s	remaining: 1.74s
# 4683:	total: 25.7s	remaining: 1.74s
# 4684:	total: 25.7s	remaining: 1.73s
# 4685:	total: 25.7s	remaining: 1.72s
# 4686:	total: 25.7s	remaining: 1.72s
# 4687:	total: 25.7s	remaining: 1.71s
# 4688:	total: 25.7s	remaining: 1.71s
# 4689:	total: 25.8s	remaining: 1.7s
# 4690:	total: 25.8s	remaining: 1.7s
# 4691:	total: 25.8s	remaining: 1.69s
# 4692:	total: 25.8s	remaining: 1.69s
# 4693:	total: 25.8s	remaining: 1.68s
# 4694:	total: 25.8s	remaining: 1.67s
# 4695:	total: 25.8s	remaining: 1.67s
# 4696:	total: 25.8s	remaining: 1.66s
# 4697:	total: 25.8s	remaining: 1.66s
# 4698:	total: 25.8s	remaining: 1.65s
# 4699:	total: 25.8s	remaining: 1.65s
# 4700:	total: 25.8s	remaining: 1.64s
# 4701:	total: 25.8s	remaining: 1.64s
# 4702:	total: 25.8s	remaining: 1.63s
# 4703:	total: 25.8s	remaining: 1.63s
# 4704:	total: 25.8s	remaining: 1.62s
# 4705:	total: 25.8s	remaining: 1.61s
# 4706:	total: 25.8s	remaining: 1.61s
# 4707:	total: 25.9s	remaining: 1.6s
# 4708:	total: 25.9s	remaining: 1.6s
# 4709:	total: 25.9s	remaining: 1.59s
# 4710:	total: 25.9s	remaining: 1.59s
# 4711:	total: 25.9s	remaining: 1.58s
# 4712:	total: 25.9s	remaining: 1.58s
# 4713:	total: 25.9s	remaining: 1.57s
# 4714:	total: 25.9s	remaining: 1.56s
# 4715:	total: 25.9s	remaining: 1.56s
# 4716:	total: 25.9s	remaining: 1.55s
# 4717:	total: 25.9s	remaining: 1.55s
# 4718:	total: 25.9s	remaining: 1.54s
# 4719:	total: 25.9s	remaining: 1.54s
# 4720:	total: 25.9s	remaining: 1.53s
# 4721:	total: 25.9s	remaining: 1.53s
# 4722:	total: 25.9s	remaining: 1.52s
# 4723:	total: 25.9s	remaining: 1.51s
# 4724:	total: 25.9s	remaining: 1.51s
# 4725:	total: 26s	remaining: 1.5s
# 4726:	total: 26s	remaining: 1.5s
# 4727:	total: 26s	remaining: 1.49s
# 4728:	total: 26s	remaining: 1.49s
# 4729:	total: 26s	remaining: 1.48s
# 4730:	total: 26s	remaining: 1.48s
# 4731:	total: 26s	remaining: 1.47s
# 4732:	total: 26s	remaining: 1.47s
# 4733:	total: 26s	remaining: 1.46s
# 4734:	total: 26s	remaining: 1.46s
# 4735:	total: 26s	remaining: 1.45s
# 4736:	total: 26s	remaining: 1.44s
# 4737:	total: 26s	remaining: 1.44s
# 4738:	total: 26s	remaining: 1.43s
# 4739:	total: 26s	remaining: 1.43s
# 4740:	total: 26s	remaining: 1.42s
# 4741:	total: 26s	remaining: 1.42s
# 4742:	total: 26s	remaining: 1.41s
# 4743:	total: 26.1s	remaining: 1.41s
# 4744:	total: 26.1s	remaining: 1.4s
# 4745:	total: 26.1s	remaining: 1.4s
# 4746:	total: 26.1s	remaining: 1.39s
# 4747:	total: 26.1s	remaining: 1.38s
# 4748:	total: 26.1s	remaining: 1.38s
# 4749:	total: 26.1s	remaining: 1.37s
# 4750:	total: 26.1s	remaining: 1.37s
# 4751:	total: 26.1s	remaining: 1.36s
# 4752:	total: 26.1s	remaining: 1.36s
# 4753:	total: 26.1s	remaining: 1.35s
# 4754:	total: 26.1s	remaining: 1.34s
# 4755:	total: 26.1s	remaining: 1.34s
# 4756:	total: 26.1s	remaining: 1.33s
# 4757:	total: 26.1s	remaining: 1.33s
# 4758:	total: 26.1s	remaining: 1.32s
# 4759:	total: 26.1s	remaining: 1.32s
# 4760:	total: 26.1s	remaining: 1.31s
# 4761:	total: 26.2s	remaining: 1.31s
# 4762:	total: 26.2s	remaining: 1.3s
# 4763:	total: 26.2s	remaining: 1.3s
# 4764:	total: 26.2s	remaining: 1.29s
# 4765:	total: 26.2s	remaining: 1.28s
# 4766:	total: 26.2s	remaining: 1.28s
# 4767:	total: 26.2s	remaining: 1.27s
# 4768:	total: 26.2s	remaining: 1.27s
# 4769:	total: 26.2s	remaining: 1.26s
# 4770:	total: 26.2s	remaining: 1.26s
# 4771:	total: 26.2s	remaining: 1.25s
# 4772:	total: 26.2s	remaining: 1.25s
# 4773:	total: 26.2s	remaining: 1.24s
# 4774:	total: 26.2s	remaining: 1.24s
# 4775:	total: 26.2s	remaining: 1.23s
# 4776:	total: 26.2s	remaining: 1.22s
# 4777:	total: 26.2s	remaining: 1.22s
# 4778:	total: 26.2s	remaining: 1.21s
# 4779:	total: 26.3s	remaining: 1.21s
# 4780:	total: 26.3s	remaining: 1.2s
# 4781:	total: 26.3s	remaining: 1.2s
# 4782:	total: 26.3s	remaining: 1.19s
# 4783:	total: 26.3s	remaining: 1.19s
# 4784:	total: 26.3s	remaining: 1.18s
# 4785:	total: 26.3s	remaining: 1.18s
# 4786:	total: 26.3s	remaining: 1.17s
# 4787:	total: 26.3s	remaining: 1.16s
# 4788:	total: 26.3s	remaining: 1.16s
# 4789:	total: 26.3s	remaining: 1.15s
# 4790:	total: 26.3s	remaining: 1.15s
# 4791:	total: 26.3s	remaining: 1.14s
# 4792:	total: 26.3s	remaining: 1.14s
# 4793:	total: 26.3s	remaining: 1.13s
# 4794:	total: 26.3s	remaining: 1.13s
# 4795:	total: 26.3s	remaining: 1.12s
# 4796:	total: 26.4s	remaining: 1.11s
# 4797:	total: 26.4s	remaining: 1.11s
# 4798:	total: 26.4s	remaining: 1.1s
# 4799:	total: 26.4s	remaining: 1.1s
# 4800:	total: 26.4s	remaining: 1.09s
# 4801:	total: 26.4s	remaining: 1.09s
# 4802:	total: 26.4s	remaining: 1.08s
# 4803:	total: 26.4s	remaining: 1.08s
# 4804:	total: 26.4s	remaining: 1.07s
# 4805:	total: 26.4s	remaining: 1.06s
# 4806:	total: 26.4s	remaining: 1.06s
# 4807:	total: 26.4s	remaining: 1.05s
# 4808:	total: 26.4s	remaining: 1.05s
# 4809:	total: 26.4s	remaining: 1.04s
# 4810:	total: 26.4s	remaining: 1.04s
# 4811:	total: 26.4s	remaining: 1.03s
# 4812:	total: 26.4s	remaining: 1.03s
# 4813:	total: 26.4s	remaining: 1.02s
# 4814:	total: 26.4s	remaining: 1.02s
# 4815:	total: 26.5s	remaining: 1.01s
# 4816:	total: 26.5s	remaining: 1s
# 4817:	total: 26.5s	remaining: 1000ms
# 4818:	total: 26.5s	remaining: 994ms
# 4819:	total: 26.5s	remaining: 989ms
# 4820:	total: 26.5s	remaining: 983ms
# 4821:	total: 26.5s	remaining: 978ms
# 4822:	total: 26.5s	remaining: 972ms
# 4823:	total: 26.5s	remaining: 967ms
# 4824:	total: 26.5s	remaining: 961ms
# 4825:	total: 26.5s	remaining: 956ms
# 4826:	total: 26.5s	remaining: 950ms
# 4827:	total: 26.5s	remaining: 945ms
# 4828:	total: 26.5s	remaining: 939ms
# 4829:	total: 26.5s	remaining: 934ms
# 4830:	total: 26.5s	remaining: 928ms
# 4831:	total: 26.5s	remaining: 923ms
# 4832:	total: 26.5s	remaining: 917ms
# 4833:	total: 26.6s	remaining: 912ms
# 4834:	total: 26.6s	remaining: 906ms
# 4835:	total: 26.6s	remaining: 901ms
# 4836:	total: 26.6s	remaining: 895ms
# 4837:	total: 26.6s	remaining: 890ms
# 4838:	total: 26.6s	remaining: 884ms
# 4839:	total: 26.6s	remaining: 879ms
# 4840:	total: 26.6s	remaining: 873ms
# 4841:	total: 26.6s	remaining: 868ms
# 4842:	total: 26.6s	remaining: 862ms
# 4843:	total: 26.6s	remaining: 857ms
# 4844:	total: 26.6s	remaining: 851ms
# 4845:	total: 26.6s	remaining: 846ms
# 4846:	total: 26.6s	remaining: 840ms
# 4847:	total: 26.6s	remaining: 835ms
# 4848:	total: 26.6s	remaining: 829ms
# 4849:	total: 26.6s	remaining: 824ms
# 4850:	total: 26.6s	remaining: 818ms
# 4851:	total: 26.6s	remaining: 813ms
# 4852:	total: 26.7s	remaining: 807ms
# 4853:	total: 26.7s	remaining: 802ms
# 4854:	total: 26.7s	remaining: 796ms
# 4855:	total: 26.7s	remaining: 791ms
# 4856:	total: 26.7s	remaining: 785ms
# 4857:	total: 26.7s	remaining: 780ms
# 4858:	total: 26.7s	remaining: 774ms
# 4859:	total: 26.7s	remaining: 769ms
# 4860:	total: 26.7s	remaining: 763ms
# 4861:	total: 26.7s	remaining: 758ms
# 4862:	total: 26.7s	remaining: 752ms
# 4863:	total: 26.7s	remaining: 747ms
# 4864:	total: 26.7s	remaining: 741ms
# 4865:	total: 26.7s	remaining: 736ms
# 4866:	total: 26.7s	remaining: 730ms
# 4867:	total: 26.7s	remaining: 725ms
# 4868:	total: 26.7s	remaining: 719ms
# 4869:	total: 26.7s	remaining: 714ms
# 4870:	total: 26.8s	remaining: 709ms
# 4871:	total: 26.8s	remaining: 703ms
# 4872:	total: 26.8s	remaining: 698ms
# 4873:	total: 26.8s	remaining: 692ms
# 4874:	total: 26.8s	remaining: 687ms
# 4875:	total: 26.8s	remaining: 681ms
# 4876:	total: 26.8s	remaining: 676ms
# 4877:	total: 26.8s	remaining: 670ms
# 4878:	total: 26.8s	remaining: 665ms
# 4879:	total: 26.8s	remaining: 659ms
# 4880:	total: 26.8s	remaining: 654ms
# 4881:	total: 26.8s	remaining: 648ms
# 4882:	total: 26.8s	remaining: 643ms
# 4883:	total: 26.8s	remaining: 637ms
# 4884:	total: 26.8s	remaining: 632ms
# 4885:	total: 26.8s	remaining: 626ms
# 4886:	total: 26.8s	remaining: 621ms
# 4887:	total: 26.8s	remaining: 615ms
# 4888:	total: 26.9s	remaining: 610ms
# 4889:	total: 26.9s	remaining: 604ms
# 4890:	total: 26.9s	remaining: 599ms
# 4891:	total: 26.9s	remaining: 593ms
# 4892:	total: 26.9s	remaining: 588ms
# 4893:	total: 26.9s	remaining: 582ms
# 4894:	total: 26.9s	remaining: 577ms
# 4895:	total: 26.9s	remaining: 571ms
# 4896:	total: 26.9s	remaining: 566ms
# 4897:	total: 26.9s	remaining: 560ms
# 4898:	total: 26.9s	remaining: 555ms
# 4899:	total: 26.9s	remaining: 549ms
# 4900:	total: 26.9s	remaining: 544ms
# 4901:	total: 26.9s	remaining: 538ms
# 4902:	total: 26.9s	remaining: 533ms
# 4903:	total: 26.9s	remaining: 527ms
# 4904:	total: 26.9s	remaining: 522ms
# 4905:	total: 26.9s	remaining: 516ms
# 4906:	total: 26.9s	remaining: 511ms
# 4907:	total: 27s	remaining: 505ms
# 4908:	total: 27s	remaining: 500ms
# 4909:	total: 27s	remaining: 494ms
# 4910:	total: 27s	remaining: 489ms
# 4911:	total: 27s	remaining: 483ms
# 4912:	total: 27s	remaining: 478ms
# 4913:	total: 27s	remaining: 472ms
# 4914:	total: 27s	remaining: 467ms
# 4915:	total: 27s	remaining: 461ms
# 4916:	total: 27s	remaining: 456ms
# 4917:	total: 27s	remaining: 450ms
# 4918:	total: 27s	remaining: 445ms
# 4919:	total: 27s	remaining: 439ms
# 4920:	total: 27s	remaining: 434ms
# 4921:	total: 27s	remaining: 428ms
# 4922:	total: 27s	remaining: 423ms
# 4923:	total: 27s	remaining: 417ms
# 4924:	total: 27s	remaining: 412ms
# 4925:	total: 27.1s	remaining: 406ms
# 4926:	total: 27.1s	remaining: 401ms
# 4927:	total: 27.1s	remaining: 395ms
# 4928:	total: 27.1s	remaining: 390ms
# 4929:	total: 27.1s	remaining: 384ms
# 4930:	total: 27.1s	remaining: 379ms
# 4931:	total: 27.1s	remaining: 373ms
# 4932:	total: 27.1s	remaining: 368ms
# 4933:	total: 27.1s	remaining: 362ms
# 4934:	total: 27.1s	remaining: 357ms
# 4935:	total: 27.1s	remaining: 351ms
# 4936:	total: 27.1s	remaining: 346ms
# 4937:	total: 27.1s	remaining: 340ms
# 4938:	total: 27.1s	remaining: 335ms
# 4939:	total: 27.1s	remaining: 329ms
# 4940:	total: 27.1s	remaining: 324ms
# 4941:	total: 27.1s	remaining: 318ms
# 4942:	total: 27.1s	remaining: 313ms
# 4943:	total: 27.1s	remaining: 307ms
# 4944:	total: 27.1s	remaining: 302ms
# 4945:	total: 27.2s	remaining: 296ms
# 4946:	total: 27.2s	remaining: 291ms
# 4947:	total: 27.2s	remaining: 285ms
# 4948:	total: 27.2s	remaining: 280ms
# 4949:	total: 27.2s	remaining: 275ms
# 4950:	total: 27.2s	remaining: 269ms
# 4951:	total: 27.2s	remaining: 264ms
# 4952:	total: 27.2s	remaining: 258ms
# 4953:	total: 27.2s	remaining: 253ms
# 4954:	total: 27.2s	remaining: 247ms
# 4955:	total: 27.2s	remaining: 242ms
# 4956:	total: 27.2s	remaining: 236ms
# 4957:	total: 27.2s	remaining: 231ms
# 4958:	total: 27.2s	remaining: 225ms
# 4959:	total: 27.2s	remaining: 220ms
# 4960:	total: 27.2s	remaining: 214ms
# 4961:	total: 27.2s	remaining: 209ms
# 4962:	total: 27.2s	remaining: 203ms
# 4963:	total: 27.2s	remaining: 198ms
# 4964:	total: 27.3s	remaining: 192ms
# 4965:	total: 27.3s	remaining: 187ms
# 4966:	total: 27.3s	remaining: 181ms
# 4967:	total: 27.3s	remaining: 176ms
# 4968:	total: 27.3s	remaining: 170ms
# 4969:	total: 27.3s	remaining: 165ms
# 4970:	total: 27.3s	remaining: 159ms
# 4971:	total: 27.3s	remaining: 154ms
# 4972:	total: 27.3s	remaining: 148ms
# 4973:	total: 27.3s	remaining: 143ms
# 4974:	total: 27.3s	remaining: 137ms
# 4975:	total: 27.3s	remaining: 132ms
# 4976:	total: 27.3s	remaining: 126ms
# 4977:	total: 27.3s	remaining: 121ms
# 4978:	total: 27.3s	remaining: 115ms
# 4979:	total: 27.3s	remaining: 110ms
# 4980:	total: 27.3s	remaining: 104ms
# 4981:	total: 27.3s	remaining: 98.8ms
# 4982:	total: 27.3s	remaining: 93.3ms
# 4983:	total: 27.4s	remaining: 87.8ms
# 4984:	total: 27.4s	remaining: 82.3ms
# 4985:	total: 27.4s	remaining: 76.8ms
# 4986:	total: 27.4s	remaining: 71.3ms
# 4987:	total: 27.4s	remaining: 65.9ms
# 4988:	total: 27.4s	remaining: 60.4ms
# 4989:	total: 27.4s	remaining: 54.9ms
# 4990:	total: 27.4s	remaining: 49.4ms
# 4991:	total: 27.4s	remaining: 43.9ms
# 4992:	total: 27.4s	remaining: 38.4ms
# 4993:	total: 27.4s	remaining: 32.9ms
# 4994:	total: 27.4s	remaining: 27.4ms
# 4995:	total: 27.4s	remaining: 22ms
# 4996:	total: 27.4s	remaining: 16.5ms
# 4997:	total: 27.4s	remaining: 11ms
# 4998:	total: 27.4s	remaining: 5.49ms
# 4999:	total: 27.4s	remaining: 0us
# Training LightGBM model...
# [LightGBM] [Info] Number of positive: 15458, number of negative: 75768
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.067342 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2411
# [LightGBM] [Info] Number of data points in the train set: 91226, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.169447 -> initscore=-1.589549
# [LightGBM] [Info] Start training from score -1.589549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training XGBoost model...

# %% [markdown]
# # Новый раздел
